# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import plotly.express as px

# %%
RY_raw = pd.read_csv ("C:\\Users\\Utilisateur\\Desktop\\csv\\dataset_csv.csv ")

# %%
RY_raw.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 2512  2019-11-14  81.709999  81.809998  81.459999  81.769997  81.769997
# 2513  2019-11-15  81.839996  82.269997  81.709999  82.260002  82.260002
# 2514  2019-11-18  82.040001  82.459999  82.019997  82.349998  82.349998
# 2515  2019-11-19  82.389999  82.440002  81.910004  82.000000  82.000000
# 2516  2019-11-20  81.769997  82.110001  81.660004  81.809998  81.809998
#
#       Volume
# 2512  435200
# 2513  634400
# 2514  546200
# 2515  612400
# 2516  996200

# %%
plt.figure()
plt.plot(RY_raw["Open"])
plt.plot(RY_raw["High"])
plt.plot(RY_raw["Low"])
plt.plot(RY_raw["Close"])
plt.title('Royal Bank of Canada Stock Price History')
plt.ylabel('Price (CAD) ')
plt.xlabel('Days')
plt.legend(['Open','High','Low','Close'], loc = 'upper left')
plt.show()

# %%
plt.figure()
plt.plot(RY_raw["Close"])
plt.title('Royal Bank of Canada Stock Price History')
plt.ylabel('Price (CAD) ')
plt.xlabel('Days')
plt.legend(['Close'], loc = 'upper left')
plt.show()

# %%
plt.figure()
plt.plot(RY_raw["Open"])
plt.title('Royal Bank of Canada Stock Price History')
plt.ylabel('Price (CAD) ')
plt.xlabel('Days')
plt.legend(['Open'], loc = 'upper left')
plt.show()

# %%
plt.figure()
plt.plot(RY_raw["High"])
plt.title('Royal Bank of Canada Stock Price History')
plt.ylabel('Price (CAD) ')
plt.xlabel('Days')
plt.legend(['High'], loc = 'upper left')
plt.show()

# %%
plt.figure()
plt.plot(RY_raw["Volume"])
plt.title('Royal Bank of Canada')
plt.ylabel('Volume ')
plt.xlabel('Days')
plt.legend(['Volume'], loc = 'upper left')
plt.show()

# %%
plt.figure()
plt.plot(RY_raw["Year"], RY_raw["Volume"])
plt.title('Royal Bank of Canada: Stock Volume by Year')
plt.ylabel('Volume ')
plt.xlabel('Year')
plt.legend(['Volume'], loc = 'upper left')
plt.show()

# %%
RY_raw['Date'] = pd.to_datetime(RY_raw.Date,format='%Y-%m-%d')
RY_raw.index = RY_raw['Date']

# %%
Stationarity_check_closeprice= RY_raw['Close']

# %%
RY_new_data
# Out:
#                      Date  Close
# 0     2009-11-20 00:00:00  53.94
# 1     2009-11-23 00:00:00  55.07
# 2     2009-11-24 00:00:00  54.28
# 3     2009-11-25 00:00:00  54.64
# 4     2009-11-27 00:00:00  53.24
# ...                   ...    ...
# 2512  2019-11-14 00:00:00  81.77
# 2513  2019-11-15 00:00:00  82.26
# 2514  2019-11-18 00:00:00  82.35
# 2515  2019-11-19 00:00:00     82
# 2516  2019-11-20 00:00:00  81.81
#
# [2517 rows x 2 columns]

# %%
Stationarity_check_closeprice
# Out:
# Date
# 2009-11-20    53.939999
# 2009-11-23    55.070000
# 2009-11-24    54.279999
# 2009-11-25    54.639999
# 2009-11-27    53.240002
#                 ...
# 2019-11-14    81.769997
# 2019-11-15    82.260002
# 2019-11-18    82.349998
# 2019-11-19    82.000000
# 2019-11-20    81.809998
# Name: Close, Length: 2517, dtype: float64

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Transformation to log
log_closeprice = np.log(Stationarity_check_closeprice)
moving_avg = log_closeprice.rolling(12).mean()
std_dev = log_closeprice.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.show()
# Move to moving Average
# Out:
# No handles with labels found to put in legend.

# %%
RY_raw.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
RY_raw.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2517.000000  2517.000000  2517.000000  2517.000000  2517.000000
# mean     63.981625    64.397652    63.539090    63.992527    53.036870
# std       9.915361     9.886003     9.960775     9.919575    13.828898
# min      41.849998    42.070000    41.400002    41.430000    29.803961
# 25%      56.099998    56.570000    55.680000    56.209999    41.775330
# 50%      62.180000    62.549999    61.790001    62.209999    50.800888
# 75%      73.050003    73.489998    72.610001    72.970001    64.452400
# max      86.709999    87.099998    86.500000    86.750000    82.349998
#
#              Volume
# count  2.517000e+03
# mean   8.906182e+05
# std    5.708480e+05
# min    1.327000e+05
# 25%    5.423000e+05
# 50%    7.630000e+05
# 75%    1.089400e+06
# max    9.830200e+06

# %%
RY_raw.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
from datetime import date

# %%
RY_raw.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
RY_raw['Year'] = pd.DatetimeIndex(RY_raw['Date']).year

# %%
RY_raw['Date'] = pd.to_datetime(RY_raw.Date,format='%Y-%m-%d')
RY_raw.index = RY_raw['Date']

# %%
RY_raw['Month'] = pd.DatetimeIndex(RY_raw['Date']).month

# %%
RY_raw['Day'] = pd.DatetimeIndex(RY_raw['Date']).day

# %%
#Convert Date from datatype object to datetime
RY_raw['Date'] = pd.to_datetime(RY_raw['Date'])

# %%
RY_raw['WeekofYear'] = RY_raw['Date'].dt.week

# %%
RY_raw['WeekDay'] = RY_raw['Date'].dt.dayofweek
#The day of the week with Monday=0, Sunday=6.
#Series.dt.dayofweek/weekday/day_name"

# %%
RY_raw.head()
# Out:
#                  Date       Open       High        Low      Close  Adj Close  \
# Date
# 2009-11-20 2009-11-20  53.570000  54.029999  53.560001  53.939999  36.015869
# 2009-11-23 2009-11-23  54.860001  55.450001  54.860001  55.070000  36.770374
# 2009-11-24 2009-11-24  55.220001  55.330002  54.200001  54.279999  36.242901
# 2009-11-25 2009-11-25  54.650002  55.180000  54.549999  54.639999  36.483265
# 2009-11-27 2009-11-27  51.700001  53.680000  51.299999  53.240002  35.548489
#
#              Volume
# Date
# 2009-11-20   647900
# 2009-11-23   770400
# 2009-11-24  1097500
# 2009-11-25   652000
# 2009-11-27   759300

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\contr\anaconda3\lib\site-packages (4.4.1)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\contr\anaconda3\lib\site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in c:\users\contr\anaconda3\lib\site-packages (from plotly) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
RY_new_date.tail()
# Out:
#                      Date  Close
# 2512  2019-11-14 00:00:00  81.77
# 2513  2019-11-15 00:00:00  82.26
# 2514  2019-11-18 00:00:00  82.35
# 2515  2019-11-19 00:00:00     82
# 2516  2019-11-20 00:00:00  81.81

# %%
RY_train, RY_test = train_test_split(RY_new_date, train_size = 0.7, test_size = 0.3, shuffle = False)

# %%
# Plotting the test and the train data log_closeprice
#train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
RY_log_train, RY_log_test = train_test_split(log_closeprice, train_size = 0.7, test_size = 0.3, shuffle = False)
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(log_closeprice, 'green', label='Train data')
plt.plot(RY_log_test, 'yellow', label='Test data')
plt.legend()

# %%
type(RY_log_train)
# Out:
# pandas.core.series.Series

# %%
# converting train series to frame
RY_df_log_train=RY_log_train#.to_frame().reset_index()
RY_df_log_train.reset_index(name='Close')
TR_Log_Price= RY_df_log_train.to_frame(name='Close')

# %%
log_closeprice
# Out:
# Date
# 2009-11-20    3.987872
# 2009-11-23    4.008605
# 2009-11-24    3.994156
# 2009-11-25    4.000766
# 2009-11-27    3.974810
#                 ...
# 2019-11-14    4.403910
# 2019-11-15    4.409885
# 2019-11-18    4.410978
# 2019-11-19    4.406719
# 2019-11-20    4.404399
# Name: Close, Length: 2517, dtype: float64

# %%
TR_Log_Price
# Out:
#                Close
# Date
# 2009-11-20  3.987872
# 2009-11-23  4.008605
# 2009-11-24  3.994156
# 2009-11-25  4.000766
# 2009-11-27  3.974810
# ...              ...
# 2016-11-11  4.150567
# 2016-11-14  4.157163
# 2016-11-15  4.158727
# 2016-11-16  4.159039
# 2016-11-17  4.164181
#
# [1761 rows x 1 columns]

# %%
RY_df_log_test=RY_log_test#.to_frame().reset_index()
RY_df_log_test.reset_index(name='Close')
Test_Log_Price_LR= RY_df_log_test.to_frame(name='Close')
Test_Log_Price= RY_df_log_test.to_frame(name='Close')

# %%
Test_Log_Price_LR= RY_df_log_test.to_frame(name='Close')

# %%
#Test_Log_Price_LR
TR_Log_Price
# Out:
#                Close
# Date
# 2009-11-20  3.987872
# 2009-11-23  4.008605
# 2009-11-24  3.994156
# 2009-11-25  4.000766
# 2009-11-27  3.974810
# ...              ...
# 2016-11-11  4.150567
# 2016-11-14  4.157163
# 2016-11-15  4.158727
# 2016-11-16  4.159039
# 2016-11-17  4.164181
#
# [1761 rows x 1 columns]

# %%
print('\n Shape of Training set:')
print(RY_df_log_train.shape)
RY_train
# Out:
#  Shape of Training set:
# (1761, 1)
#                      Date  Close
# 0     2009-11-20 00:00:00  53.94
# 1     2009-11-23 00:00:00  55.07
# 2     2009-11-24 00:00:00  54.28
# 3     2009-11-25 00:00:00  54.64
# 4     2009-11-27 00:00:00  53.24
# ...                   ...    ...
# 1756  2016-11-11 00:00:00  63.47
# 1757  2016-11-14 00:00:00  63.89
# 1758  2016-11-15 00:00:00  63.99
# 1759  2016-11-16 00:00:00  64.01
# 1760  2016-11-17 00:00:00  64.34
#
# [1761 rows x 2 columns]

# %%
print('\n Shape of Test set:')
print(RY_test.shape)
RY_test
# Out:
#  Shape of Test set:
# (756, 3)
#                      Date  Close  Predictions
# 1761  2016-11-18 00:00:00  64.55    62.810820
# 1762  2016-11-21 00:00:00  66.37    62.803242
# 1763  2016-11-22 00:00:00  66.33    62.795614
# 1764  2016-11-23 00:00:00  66.59    62.788716
# 1765  2016-11-25 00:00:00  66.53    62.781810
# ...                   ...    ...          ...
# 2512  2019-11-14 00:00:00  81.77    60.972686
# 2513  2019-11-15 00:00:00  82.26    60.969383
# 2514  2019-11-18 00:00:00  82.35    60.965520
# 2515  2019-11-19 00:00:00     82    60.961519
# 2516  2019-11-20 00:00:00  81.81    60.957487
#
# [756 rows x 3 columns]

# %%
print(RY_df_log_test.shape)
# Out:
# (756, 1)

# %%
#moving AVerage: Create predictions for the validation set and check the RMSE using the actual values.
# making predictions
preds = []
for i in range(0, RY_test.shape[0]):
    a = RY_train['Close'][len(RY_train)- 756 + i:] .sum() + sum(preds)
    b = a/756
    preds.append(b)
    
    # 50, RMSE =13366485
    #500, RMSE = 14.9
    #756, RMSE =15.8 
    #250 130
    #300, 67
    #270, 98

# %%
preds1 = []
for i in range(0, Test_Log_Price.shape[0]):
    a = TR_Log_Price['Close'][len(TR_Log_Price)- 756 + i:] .sum() + sum(preds1)
    b = a/756
    preds1.append(b)

# %%
from sklearn.metrics import mean_squared_error

# %%
#MA_MAPE = np.mean(np.abs(np.array(preds-RY_test['Close'])/np.abs(RY_test['Close']))) 
#print(MA_MAPE) 0.24834066045880754

log_MA_mse = mean_squared_error(Test_Log_Price['Close'], preds1)
print('MSE with naive approach : ', log_MA_mse)

log_MA_rmse = np.sqrt(mean_squared_error(Test_Log_Price['Close'], preds1))
print('RMSE with naive approach : ', log_MA_rmse)
# Out:
# MSE with naive approach :  0.05452857704599903
# RMSE with naive approach :  0.23351354788534012

# %%
MA_MAPE = np.mean(np.abs(np.array(preds-RY_test['Close'])/np.abs(RY_test['Close']))) 
#print(MA_MAPE) 0.24834066045880754

mse = mean_squared_error(RY_test['Close'], preds)
print('MSE with naive approach : ', mse) #250

rmse = np.sqrt(mean_squared_error(RY_test['Close'], preds))
print('RMSE with naive approach : ', rmse)#RSME value on validation set:
15.811643717557098
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-317-0d96dc00e665> in <module>
# ----> 1 MA_MAPE = np.mean(np.abs(np.array(preds-RY_test['Close'])/np.abs(RY_test['Close'])))
#       2 #print(MA_MAPE) 0.24834066045880754
#       3
#       4 mse = mean_squared_error(RY_test['Close'], preds)
#       5 print('MSE with naive approach : ', mse)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     966
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#     970             result = masked_arith_op(x, y, op)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     219     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#     223
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     125
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#     129     return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\roperator.py in rsub(left, right)
#      11
#      12 def rsub(left, right):
# ---> 13     return right - left
#      14
#      15
#
# ValueError: operands could not be broadcast together with shapes (3024,) (756,)

# %%
#Checking the results (RMSEValue)

MA_rms=np.sqrt(np.mean(np.power((np.array(RY_test['Close'])-preds),2)))
print('\n RSME value on validation set:')
print(MA_rms)
# Out:
#  RSME value on validation set:
# 15.811643717557098

# %%
MA_mse=np.mean(np.power((np.array(RY_test['Close'])-preds),2))
print('\n MSE value on validation set:')
print(MA_mse)
# Out:
#  MSE value on validation set:
# 250.00807705096284

# %%
# PLot Prediction of Moving Average
RY_test['Predictions'] = 0
RY_test['Predictions'] = preds
plt.plot(RY_train['Close'])
plt.plot(RY_test[['Close','Predictions']])
# Out:
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [<matplotlib.lines.Line2D at 0x1f8f6be9948>,
#  <matplotlib.lines.Line2D at 0x1f8f6be9b48>]

# %%
# PLot Prediction of Moving Average
Test_Log_Price['Predictions'] = 0
Test_Log_Price['Predictions'] = preds1
plt.plot(TR_Log_Price['Close'])
plt.plot(Test_Log_Price[['Close','Predictions']])
# Out:
# [<matplotlib.lines.Line2D at 0x1f882b3c808>,
#  <matplotlib.lines.Line2D at 0x1f882b3c948>]

# %%
LSTM_base_closeprice =log_closeprice
#LSTM_base_closeprice.reset_index(name='Close')
#LSTM_base_closeprice.reset_index(level=0, inplace=True)
#LSTM_log_base_closeprice= LSTM_base_closeprice.to_frame(name='Close')

# %%
log_base_closeprice.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-446-3f7b6944fd87> in <module>
# ----> 1 log_base_closeprice.shape()
#
# TypeError: 'tuple' object is not callable

# %%
LSTM_log_base_closeprice.rename(columns={'new name': 'Date'}, inplace=True)

# %%
#converting index column to dataframe column by reeducing the level
log_base_closeprice.shape (2517, 1)
log_base_closeprice
log_base_closeprice.reset_index(level=0, inplace=True)
# log_base_closeprice['Date'] = log_base_closeprice['new name'] log_base_closeprice = log_base_closeprice.drop('Date',1)
log_base_closeprice.rename(columns={'new name': 'Date'}, inplace=True)
# Out:
#            Date     Close
# 0    2009-11-20  3.987872
# 1    2009-11-23  4.008605
# 2    2009-11-24  3.994156
# 3    2009-11-25  4.000766
# 4    2009-11-27  3.974810
# ...         ...       ...
# 2512 2019-11-14  4.403910
# 2513 2019-11-15  4.409885
# 2514 2019-11-18  4.410978
# 2515 2019-11-19  4.406719
# 2516 2019-11-20  4.404399
#
# [2517 rows x 2 columns]

# %%
for i in range(0, len(RY_raw_new)):
    RY_RW_sub['Date'][i] = RY_raw_new['Date'][i]
    RY_RW_sub['Close'][i] = RY_raw_new['Close'][i]

# %%
RY_RW_sub.head()
# Out:
#                   Date  Close
# 0  2009-11-20 00:00:00  53.94
# 1  2009-11-23 00:00:00  55.07
# 2  2009-11-24 00:00:00  54.28
# 3  2009-11-25 00:00:00  54.64
# 4  2009-11-27 00:00:00  53.24

# %%
RY_train, RY_test = train_test_split(RY_RW_sub, train_size = 0.7, test_size = 0.3, shuffle = False)

# %%
RY_train.head()
# Out:
#                   Date  Close
# 0  2009-11-20 00:00:00  53.94
# 1  2009-11-23 00:00:00  55.07
# 2  2009-11-24 00:00:00  54.28
# 3  2009-11-25 00:00:00  54.64
# 4  2009-11-27 00:00:00  53.24

# %%
RY_LR_log_train, RY_LR_log_test = train_test_split(log_base_closeprice, train_size = 0.7, test_size = 0.3, shuffle = False)

# %%
x_LR_RY_train = RY_LR_log_train.drop('Close', axis = 1)
y_LR_RY_train = RY_LR_log_train['Close']

# %%
x_LR_RY_test = RY_LR_log_test.drop('Close', axis = 1)
y_LR_RY_test = RY_LR_log_test['Close']

# %%
y_LR_RY_test
# Out:
# 1761    4.167440
# 1762    4.195245
# 1763    4.194642
# 1764    4.198554
# 1765    4.197653
#           ...
# 2512    4.403910
# 2513    4.409885
# 2514    4.410978
# 2515    4.406719
# 2516    4.404399
# Name: Close, Length: 756, dtype: float64

# %%
xRY_test = Test_Log_Price_LR.drop('Close', axis = 1)
yRY_test = Test_Log_Price_LR['Close']

# %%
#Implement Linear Regression
from sklearn.linear_model import LinearRegression
LRmodel = LinearRegression()
LRmodel.fit(x_LR_RY_train, y_LR_RY_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
LR_log_preds = LRmodel.predict(x_LR_RY_test)

# %%
LR_log_preds
# Out:
# array([4.108206, 4.107184, 4.107286, 4.107388, ..., 4.231053, 4.230031, 4.230133, 4.230235])

# %%
# testing Linear Regression

LR_Log_MAPE = np.mean(np.abs(np.array(LR_log_preds-y_LR_RY_test)/np.abs(y_LR_RY_test))) 
print('MAPE: ', LR_Log_MAPE)

LR_log_mse = mean_squared_error(y_LR_RY_test, LR_log_preds)
print('MSE: ', LR_log_mse)

LR_log_rmse = np.sqrt(mean_squared_error(y_LR_RY_test, LR_log_preds))
print('RMSE: ', LR_log_rmse)
# Out:
# MAPE:  0.026096261847886146
# MSE:  0.015900888524423385
# RMSE:  0.12609872530847957

# %%
#Implement Linear Regression
from sklearn.linear_model import LinearRegression
LRmodel = LinearRegression()
LRmodel.fit(xRY_train, yRY_train)

# %%
#RSME
LR_log_preds = LRmodel.predict(yRY_test)

# %%
LR_MSE = np.mean(np.power((np.array(yRY_test)- np.array(LR_preds)),2))
LR_MSE # 47.37
# Out:
# 47.371212171241204

# %%
LR_rms= np.sqrt(np.mean(np.power((np.array(yRY_test)- np.array(LR_preds)),2)))
LR_rms #6.8
# Out:
# 6.8826747831959345

# %%
RY_LR_log_test['Predictions'] = 0
RY_LR_log_test['Predictions'] = LR_log_preds
# Out:
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
RY_test['Predictions'] = 0
RY_test['Predictions'] = LR_preds
# Out:
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.plot(RY_train['Close'])
plt.plot(RY_test[['Close','Predictions']])

# %%
plt.plot(RY_LR_log_train['Close'])
plt.plot(RY_LR_log_test[['Close','Predictions']])
# Out:
# [<matplotlib.lines.Line2D at 0x1f8829dd648>,
#  <matplotlib.lines.Line2D at 0x1f8829dd9c8>]

# %%
#Implementing kNN
from sklearn import neighbors
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
#scaling Data
xRY_KNN_train_scaled = scaler.fit_transform(x_LR_RY_train)
x_KNN_RY_train = pd.DataFrame(xRY_KNN_train_scaled)
xRY_KNN_test_scaled = scaler.fit_transform(x_LR_RY_test)
x_KNN_RY_test = pd.DataFrame(xRY_KNN_test_scaled)

# %%
#using Grid search to find the best parameter
params = {'n_neighbors':[2,3,4,5,6,7,8,9]}
knn = neighbors.KNeighborsRegressor()
model = GridSearchCV(knn, params, cv = 5)

# %%
#fit model and make predictions
model.fit(x_KNN_RY_train, yRY_train)
KN_preds =model.predict(x_KNN_RY_test)
# Out:
# C:\Users\contr\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning:
#
# The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.

# %%
model.fit(xRY_train, y_LR_RY_train)
KN_preds =model.predict(xRY_test)

# %%
#RSME
rms = np.sqrt(np.mean(np.power((np.array(yRY_test)-np.array(KN_preds)),2)))

rms
# Out:
# 15.114466951472247

# %%
# Testing KNN

KNN_Log_MAPE = np.mean(np.abs(np.array(KN_preds-y_LR_RY_test)/np.abs(y_LR_RY_test))) 
print('MAPE: ', KNN_Log_MAPE)

KNN_log_mse = mean_squared_error(y_LR_RY_test, KN_preds)
print('MSE: ', KNN_log_mse)

KNN_log_rmse = np.sqrt(mean_squared_error(y_LR_RY_test, KN_preds))
print('RMSE: ', KNN_log_rmse)
# Out:
# MAPE:  0.05856461499234124
# MSE:  0.07183744348480116
# RMSE:  0.2680250799548452

# %%
RY_LR_log_test['Predictions'] = 0
RY_LR_log_test['Predictions'] = KN_preds
plt.plot(RY_LR_log_train['Close'])
plt.plot(RY_LR_log_test[['Close', 'Predictions']])
# Out:
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [<matplotlib.lines.Line2D at 0x1f880166608>,
#  <matplotlib.lines.Line2D at 0x1f880166688>]

# %% [raw]
# rms

# %%
RY_test['Predictions'] = 0
RY_test['Predictions'] = KN_preds
plt.plot(RY_test[['Close', 'Predictions']])
plt.plot(RY_train['Close'])
# Out:
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
aa_train = RY_LR_log_train['Close']
aa_test = RY_LR_log_test['Close']

# %%
aa_test = RY_LR_log_test['Close']
aa_test
# Out:
# 1761    4.167440
# 1762    4.195245
# 1763    4.194642
# 1764    4.198554
# 1765    4.197653
#           ...
# 2512    4.403910
# 2513    4.409885
# 2514    4.410978
# 2515    4.406719
# 2516    4.404399
# Name: Close, Length: 756, dtype: float64

# %%
from pmdarima.arima import auto_arima

# %%
aa_model=auto_arima(aa_train, test = 'adf',startp=0, start_q=0, max_p = 3, max_q = 3, m = 12, start_P=0,seasonal =False,D=0, trace=True,error_action='ignore',suppress_warning=True)
print(aa_model.summary())
# Out:
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 0, 0, 0); AIC=-10266.450, BIC=-10244.558, Fit time=0.352 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 0, 0); AIC=-10269.531, BIC=-10258.585, Fit time=0.245 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 0, 0, 0); AIC=-10267.815, BIC=-10251.396, Fit time=0.364 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 0, 0, 0); AIC=-10267.792, BIC=-10251.373, Fit time=0.334 seconds
# C:\Users\contr\Anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 0, 0, 0); AIC=-10271.427, BIC=-10265.954, Fit time=0.100 seconds
# C:\Users\contr\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# C:\Users\contr\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 0, 0, 0); AIC=-10265.531, BIC=-10243.638, Fit time=0.250 seconds
# Total fit time: 1.663 seconds
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1761
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                5136.713
# Date:                Sun, 16 Feb 2020   AIC                         -10271.427
# Time:                        03:49:07   BIC                         -10265.954
# Sample:                             0   HQIC                        -10269.404
#                                - 1761
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0002   4.06e-06     42.085      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (Q):                       58.13   Jarque-Bera (JB):               314.85
# Prob(Q):                              0.03   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.61   Skew:                            -0.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
aa_model.fit(aa_train)
# Out:
# C:\Users\contr\Anaconda3\lib\site-packages\statsmodels\base\model.py:512: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# ARIMA(maxiter=50, method='lbfgs', order=(0, 1, 0), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=False, trend=None,
#       with_intercept=False)

# %%
aa_preds= aa_model.predict(n_periods=756)

# %%
aa_forecast = pd.DataFrame(forecast,index = RY_test.index, columns=['Prediction'])

# %%
RY_LR_log_test['Predictions'] = 0
RY_LR_log_test['Predictions'] = aa_preds
# Out:
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\contr\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Testing KNN

AA_Log_MAPE = np.mean(np.abs(np.array(aa_preds-y_LR_RY_test)/np.abs(y_LR_RY_test))) 
print('MAPE: ', AA_Log_MAPE)

AA_log_mse = mean_squared_error(y_LR_RY_test, aa_preds)
print('MSE: ', AA_log_mse)

AA_log_rmse = np.sqrt(mean_squared_error(y_LR_RY_test, aa_preds))
print('RMSE: ', AA_log_rmse)
# Out:
# MAPE:  0.038070161281049945
# MSE:  0.030422320622093112
# RMSE:  0.17441995477035624

# %%
plt.plot(RY_LR_log_train['Close'])
plt.plot(RY_LR_log_test[['Close', 'Predictions']])
# Out:
# [<matplotlib.lines.Line2D at 0x1f883f2a2c8>,
#  <matplotlib.lines.Line2D at 0x1f883f2a408>]

# %%
aa_model=auto_arima(aa_train, startp=1, start_q=1, max_p = 3, m = 12, start_P=0,seasonal =True,D=1, trace=True,error_action='ignore',suppress_warning=True)

# %%
aa_model.fit(aa_train)
# Out:
# ARIMA(maxiter=50, method='lbfgs', order=(1, 0, 0), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 1, 1, 12),
#       start_params=None, suppress_warnings=False, trend=None,
#       with_intercept=True)

# %%
forecast = aa_model.predict(n_periods=504)

# %%
len(RY_test)
# Out:
# 504

# %%
forecast = pd.DataFrame(forecast,index = RY_test.index, columns=['Prediction'])

# %%
aa_rms = np.sqrt(np.mean(np.power((np.array(RY_test['Close'])-np.array(forecast['Prediction'])),2)))

# %%
aa_rms
# Out:
# 3.522003650320063

# %%
plt.plot(RY_train['Close'])
plt.plot(RY_test['Close'])
plt.plot(forecast['Prediction'])

# %%
#Auto arima
pip install pmdarima
# Out:
#   File "<ipython-input-75-41233c6686d1>", line 2
#     pip install pmdarima
#               ^
# SyntaxError: invalid syntax

# %%
from pmdarima.arima import auto_arima

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\contr\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: pyyaml in c:\users\contr\anaconda3\lib\site-packages (from keras) (5.1.2)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\contr\anaconda3\lib\site-packages (from keras) (1.16.5)
# Requirement already satisfied: h5py in c:\users\contr\anaconda3\lib\site-packages (from keras) (2.9.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\contr\anaconda3\lib\site-packages (from keras) (1.3.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\contr\anaconda3\lib\site-packages (from keras) (1.1.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\contr\anaconda3\lib\site-packages (from keras) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\contr\anaconda3\lib\site-packages (from keras) (1.0.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install TensorFlow
# Out:
# Requirement already satisfied: TensorFlow in c:\users\contr\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (3.11.1)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (0.1.8)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (2.0.2)
# Requirement already satisfied: keras-applications>=1.0.8 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (0.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (1.16.5)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (0.8.1)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (1.11.2)
# Requirement already satisfied: wheel>=0.26 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (0.33.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (3.1.0)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (2.0.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (1.25.0)
# Requirement already satisfied: gast==0.2.2 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (0.2.2)
# Requirement already satisfied: six>=1.10.0 in c:\users\contr\anaconda3\lib\site-packages (from TensorFlow) (1.12.0)
# Requirement already satisfied: setuptools in c:\users\contr\anaconda3\lib\site-packages (from protobuf>=3.6.1->TensorFlow) (41.4.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\contr\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->TensorFlow) (3.1.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\contr\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->TensorFlow) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\contr\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->TensorFlow) (1.7.2)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\contr\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->TensorFlow) (0.16.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\contr\anaconda3\lib\site-packages (from tensorboard<2.1.0,>=2.0.0->TensorFlow) (2.22.0)
# Requirement already satisfied: h5py in c:\users\contr\anaconda3\lib\site-packages (from keras-applications>=1.0.8->TensorFlow) (2.9.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\contr\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->TensorFlow) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\contr\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->TensorFlow) (0.2.7)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in c:\users\contr\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->TensorFlow) (4.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in c:\users\contr\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->TensorFlow) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\contr\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->TensorFlow) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\contr\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->TensorFlow) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\contr\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->TensorFlow) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\contr\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->TensorFlow) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\contr\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->TensorFlow) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\contr\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->TensorFlow) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
# Out:
# Using TensorFlow backend.

# %%
base_closeprice
# Out:
# new name
# 2009-11-20    3.987872
# 2009-11-23    4.008605
# 2009-11-24    3.994156
# 2009-11-25    4.000766
# 2009-11-27    3.974810
#                 ...
# 2019-11-14    4.403910
# 2019-11-15    4.409885
# 2019-11-18    4.410978
# 2019-11-19    4.406719
# 2019-11-20    4.404399
# Length: 2517, dtype: float64

# %%
#Converting series to a dataframe
LSTM_closeprice = pd.DataFrame(LSTM_base_closeprice).reset_index()
LSTM_closeprice.columns = ['Date', 'Close']
LSTM_closeprice
# Out:
#            Date     Close
# 0    2009-11-20  3.987872
# 1    2009-11-23  4.008605
# 2    2009-11-24  3.994156
# 3    2009-11-25  4.000766
# 4    2009-11-27  3.974810
# ...         ...       ...
# 2512 2019-11-14  4.403910
# 2513 2019-11-15  4.409885
# 2514 2019-11-18  4.410978
# 2515 2019-11-19  4.406719
# 2516 2019-11-20  4.404399
#
# [2517 rows x 2 columns]

# %%
RY_RW_sub_LSTM = pd.DataFrame(index=range(0,len(RY_raw_new)),columns=['Date','Close'])

# %%
RY_RW_sub_LSTM = pd.DataFrame(index=range(0,len(LSTM_closeprice)),columns=['Date','Close'])

# %%
log_closeprice
#RY_RW_sub_LSTM = pd.DataFrame(index=range(0,len(log_closeprice)),columns=['Date','Close'])
# Out:
# new name
# 2009-11-20    3.987872
# 2009-11-23    4.008605
# 2009-11-24    3.994156
# 2009-11-25    4.000766
# 2009-11-27    3.974810
#                 ...
# 2019-11-14    4.403910
# 2019-11-15    4.409885
# 2019-11-18    4.410978
# 2019-11-19    4.406719
# 2019-11-20    4.404399
# Length: 2517, dtype: float64

# %%
for i in range(0,len(RY_raw_new)):
    RY_RW_sub_LSTM['Date'][i] = LSTM_closeprice['Date'][i]
    RY_RW_sub_LSTM['Close'][i] = LSTM_closeprice['Close'][i]

# %%
 RY_RW_sub_LSTM.head()
# Out:
#               Close
# Date
# 2009-11-20  3.98787
# 2009-11-23  4.00861
# 2009-11-24  3.99416
# 2009-11-25  4.00077
# 2009-11-27  3.97481

# %%
 RY_RW_sub_LSTM.index =  RY_RW_sub_LSTM.Date

# %%
 RY_RW_sub_LSTM.drop('Date', axis=1, inplace = True)

# %%
RY_LSTM =  RY_RW_sub_LSTM.values

# %%
len(RY_LSTM)
# Out:
# 2517

# %%
RY_LSTM_log_train, RY_LSTM_log_test = train_test_split(RY_LSTM, train_size = 0.7, test_size = 0.3, shuffle = False)RY_RW_sub_LSTM

# %%
RY_LSTM_log_test
# Out:
#               Close
# Date
# 2016-11-18  4.16744
# 2016-11-21  4.19525
# 2016-11-22  4.19464
# 2016-11-23  4.19855
# 2016-11-25  4.19765
# ...             ...
# 2019-11-14  4.40391
# 2019-11-15  4.40988
# 2019-11-18  4.41098
# 2019-11-19  4.40672
# 2019-11-20   4.4044
#
# [756 rows x 1 columns]

# %%
RY_LSTM_log_test = RY_LSTM_logplot_test
RY_LSTM_log_test.drop('Predictions', axis=1, inplace = True)
# Out:
# C:\Users\contr\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
RY_LSTM_log_train = RY_LSTM_logplot_train

# %%
RY_LSTM_log_train
# Out:
#               Close
# Date
# 2009-11-20  3.98787
# 2009-11-23  4.00861
# 2009-11-24  3.99416
# 2009-11-25  4.00077
# 2009-11-27  3.97481
# ...             ...
# 2016-11-11  4.15057
# 2016-11-14  4.15716
# 2016-11-15  4.15873
# 2016-11-16  4.15904
# 2016-11-17  4.16418
#
# [1761 rows x 1 columns]

# %%
RY_LSTM_log_test.dtype.names

# %%
RY_lstm_train = RY_LSTM[0:2013,:]

# %%
RY_lstm_test = RY_LSTM[2013:,:]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler

# %%
#Scale the data between 0 and 1
scaler = MinMaxScaler(feature_range = (0,1))

# %%
# Transforming the Data
scaled_data = scaler.fit_transform(RY_LSTM)

# %%
scaled_data
# Out:
# array([[0.357047],
#        [0.385102],
#        [0.36555 ],
#        [0.374495],
#        ...,
#        [0.928087],
#        [0.929567],
#        [0.923803],
#        [0.920664]])

# %%
xLSTM_train, yLSTM_train = [], []
for i in range(60, len(RY_lstm_train)):
    xLSTM_train.append(scaled_data[i-60:i,0])
    yLSTM_train.append(scaled_data[i,0])

# %%
xLSTM_log_train, yLSTM_log_train = [], []
for i in range(60, len(RY_LSTM_log_train)):
    xLSTM_log_train.append(scaled_data[i-60:i,0])
    yLSTM_log_train.append(scaled_data[i,0])
    xLSTM_log_train

# %%
xLSTM_log_train, yLSTM_log_train = np.array(xLSTM_log_train), np.array(yLSTM_log_train)

# %%
xLSTM_log_train.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-549-88a747d88459> in <module>
# ----> 1 xLSTM_log_train.shape()
#
# TypeError: 'tuple' object is not callable

# %%
xLSTM_log_train = np.reshape(xLSTM_log_train, (xLSTM_log_train.shape[0],xLSTM_log_train.shape[1],1))

# %%
print(xLSTM_log_train.shape)#(1701, 60, 1)
# Out:
# (1701, 60, 1)

# %%
yLSTM_log_train = np.reshape(yLSTM_log_train, (yLSTM_log_train.shape[0],yLSTM_log_train.shape[1],1))

# %%
print(yLSTM_train.shape)
# Out:
# (1953,)

# %%
xLSTM_log_train
# Out:
# array([[[0.357047],
#         [0.385102],
#         [0.36555 ],
#         [0.374495],
#         ...,
#         [0.325064],
#         [0.343686],
#         [0.360054],
#         [0.369035]],
#
#        [[0.385102],
#         [0.36555 ],
#         [0.374495],
#         [0.339372],
#         ...,
#         [0.343686],
#         [0.360054],
#         [0.369035],
#         [0.379438]],
#
#        [[0.36555 ],
#         [0.374495],
#         [0.339372],
#         [0.363304],
#         ...,
#         [0.360054],
#         [0.369035],
#         [0.379438],
#         [0.366547]],
#
#        [[0.374495],
#         [0.339372],
#         [0.363304],
#         [0.383627],
#         ...,
#         [0.369035],
#         [0.379438],
#         [0.366547],
#         [0.330703]],
#
#        ...,
#
#        [[0.565419],
#         [0.557655],
#         [0.579964],
#         [0.575276],
#         ...,
#         [0.561974],
#         [0.568426],
#         [0.581028],
#         [0.577196]],
#
#        [[0.557655],
#         [0.579964],
#         [0.575276],
#         [0.566279],
#         ...,
#         [0.568426],
#         [0.581028],
#         [0.577196],
#         [0.58612 ]],
#
#        [[0.579964],
#         [0.575276],
#         [0.566279],
#         [0.561974],
#         ...,
#         [0.581028],
#         [0.577196],
#         [0.58612 ],
#         [0.588237]],
#
#        [[0.575276],
#         [0.566279],
#         [0.561974],
#         [0.56262 ],
#         ...,
#         [0.577196],
#         [0.58612 ],
#         [0.588237],
#         [0.588659]]])

# %%
print(yLSTM_log_train.shape)#(1701,)
# Out:
# (1701,)

# %%
yLSTM_train = np.reshape(yLSTM_train, (yLSTM_train.shape[0], yLSTM_train.shape[1],1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-7d19c7e16526> in <module>
# ----> 1 yLSTM_train = np.reshape(yLSTM_train, (yLSTM_train.shape[0], yLSTM_train.shape[1],1))
#
# IndexError: tuple index out of range

# %%
#Create and fit LSTM

LSTM_log_model = Sequential()

# %%
#An LSTM layer requires a three-dimensional input and LSTMs by default will produce a two-dimensional output as
#an interpretation from the end of the sequence.We can address this by having the LSTM output a value for each time 
#step in the input data by setting the return_sequences=True argument on the layer. #This allows us to have 3D output
#from hidden LSTM layer as input to the next.
#the number of time steps and parallel series (features) are specified for the input layer via the input_shape argument.
LSTM_model.add(LSTM(units=50, return_sequences=True, input_shape=(xLSTM_train.shape[1],1)))

# %%
LSTM_log_model.add(LSTM(units=50, return_sequences=True, input_shape=(xLSTM_log_train.shape[1],1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-555-3d940f53d3c8> in <module>
# ----> 1 LSTM_log_model.add(LSTM(units=50, return_sequences=True, input_shape=(xLSTM_log_train.shape[1],1)))
#
# ~\Anaconda3\lib\site-packages\keras\engine\sequential.py in add(self, layer)
#     180                 self.inputs = network.get_source_inputs(self.outputs[0])
#     181         elif self.outputs:
# --> 182             output_tensor = layer(self.outputs[0])
#     183             if isinstance(output_tensor, list):
#     184                 raise TypeError('All layers in a Sequential model '
#
# ~\Anaconda3\lib\site-packages\keras\layers\recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     539
#     540         if initial_state is None and constants is None:
# --> 541             return super(RNN, self).__call__(inputs, **kwargs)
#     542
#     543         # If any of `initial_state` or `constants` are specified and are Keras
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     444                 # Raise exceptions in case the input is not compatible
#     445                 # with the input_spec specified in the layer constructor.
# --> 446                 self.assert_input_compatibility(inputs)
#     447
#     448                 # Collect input shapes to build layer.
#
# ~\Anaconda3\lib\site-packages\keras\engine\base_layer.py in assert_input_compatibility(self, inputs)
#     340                                      self.name + ': expected ndim=' +
#     341                                      str(spec.ndim) + ', found ndim=' +
# --> 342                                      str(K.ndim(x)))
#     343             if spec.max_ndim is not None:
#     344                 ndim = K.ndim(x)
#
# ValueError: Input 0 is incompatible with layer lstm_5: expected ndim=3, found ndim=2

# %%
from keras.layers import Dense, Activation, Flatten

# %%
#the model output shape is (None, 23, 3) whereas you want 
#it to be (None, 3). That happens because the Dense layer is 
#applied on the last axis of its input and does not 
#flatten its input automatically (if it has more than 2 dimensions).
LSTM_log_model.add(Flatten())

# %%
LSTM_log_model.add(Dense(1))

# %%
LSTM_log_model.compile(loss='mean_squared_error', optimizer='adam')

# %%
LSTM_model.fit(xLSTM_train, yLSTM_train, epochs = 1000, batch_size = 1, verbose=2, shuffle = False)
# Out:
# Epoch 1/1000
#  - 97s - loss: 0.0014
# Epoch 2/1000
#  - 97s - loss: 0.0019
# Epoch 3/1000
#  - 96s - loss: 0.0023
# Epoch 4/1000
#  - 96s - loss: 0.0018
# Epoch 5/1000
#  - 96s - loss: 0.0013
# Epoch 6/1000
#  - 100s - loss: 0.0013
# Epoch 7/1000
#  - 101s - loss: 0.0012
# Epoch 8/1000
#  - 100s - loss: 0.0013
# Epoch 9/1000
#  - 100s - loss: 0.0012
# Epoch 10/1000
#  - 94s - loss: 9.6092e-04
# Epoch 11/1000
#  - 92s - loss: 8.3972e-04
# Epoch 12/1000
#  - 92s - loss: 7.8570e-04
# Epoch 13/1000
#  - 92s - loss: 8.0656e-04
# Epoch 14/1000
#  - 92s - loss: 6.3789e-04
# Epoch 15/1000
#  - 92s - loss: 5.8782e-04
# Epoch 16/1000
#  - 93s - loss: 4.7899e-04
# Epoch 17/1000
#  - 93s - loss: 4.3436e-04
# Epoch 18/1000
#  - 92s - loss: 4.4172e-04
# Epoch 19/1000
#  - 93s - loss: 5.3741e-04
# Epoch 20/1000
#  - 92s - loss: 7.7901e-04
# Epoch 21/1000
#  - 92s - loss: 7.1194e-04
# Epoch 22/1000
#  - 92s - loss: 5.0143e-04
# Epoch 23/1000
#  - 92s - loss: 5.2138e-04
# Epoch 24/1000
#  - 91s - loss: 7.5533e-04
# Epoch 25/1000
#  - 92s - loss: 5.5320e-04
# Epoch 26/1000
#  - 868s - loss: 4.2490e-04
# Epoch 27/1000
#  - 68s - loss: 4.4437e-04
# Epoch 28/1000
#  - 48s - loss: 5.3253e-04
# Epoch 29/1000
#  - 23s - loss: 6.8934e-04
# Epoch 30/1000
#  - 23s - loss: 6.8247e-04
# Epoch 31/1000
#  - 22s - loss: 0.0101
# Epoch 32/1000
#  - 23s - loss: 7.1618e-04
# Epoch 33/1000
#  - 22s - loss: 5.5616e-04
# Epoch 34/1000
#  - 23s - loss: 4.5150e-04
# Epoch 35/1000
#  - 5842s - loss: 3.9077e-04
# Epoch 36/1000
#  - 22s - loss: 3.5040e-04
# Epoch 37/1000
#  - 22s - loss: 3.3976e-04
# Epoch 38/1000
#  - 22s - loss: 3.2945e-04
# Epoch 39/1000
#  - 22s - loss: 3.4871e-04
# Epoch 40/1000
#  - 22s - loss: 3.7253e-04
# Epoch 41/1000
#  - 22s - loss: 4.7463e-04
# Epoch 42/1000
#  - 22s - loss: 6.8446e-04
# Epoch 43/1000
#  - 22s - loss: 7.8932e-04
# Epoch 44/1000
#  - 22s - loss: 5.2241e-04
# Epoch 45/1000
#  - 22s - loss: 4.1863e-04
# Epoch 46/1000
#  - 22s - loss: 3.8990e-04
# Epoch 47/1000
#  - 22s - loss: 3.6319e-04
# Epoch 48/1000
#  - 22s - loss: 3.6697e-04
# Epoch 49/1000
#  - 22s - loss: 3.6249e-04
# Epoch 50/1000
#  - 22s - loss: 3.6581e-04
# Epoch 51/1000
#  - 22s - loss: 3.6925e-04
# Epoch 52/1000
#  - 22s - loss: 3.8703e-04
# Epoch 53/1000
#  - 22s - loss: 4.2772e-04
# Epoch 54/1000
#  - 22s - loss: 4.3569e-04
# Epoch 55/1000
#  - 22s - loss: 3.8525e-04
# Epoch 56/1000
#  - 22s - loss: 3.9054e-04
# Epoch 57/1000
#  - 22s - loss: 3.8837e-04
# Epoch 58/1000
#  - 22s - loss: 4.0228e-04
# Epoch 59/1000
#  - 22s - loss: 5.7060e-04
# Epoch 60/1000
#  - 22s - loss: 3.9267e-04
# Epoch 61/1000
#  - 22s - loss: 3.5452e-04
# Epoch 62/1000
#  - 23s - loss: 3.6438e-04
# Epoch 63/1000
#  - 22s - loss: 3.6739e-04
# Epoch 64/1000
#  - 22s - loss: 4.0196e-04
# Epoch 65/1000
#  - 22s - loss: 2.6891
# Epoch 66/1000
#  - 22s - loss: 6.6152e-04
# Epoch 67/1000
#  - 22s - loss: 4.9834e-04
# Epoch 68/1000
#  - 22s - loss: 4.7772e-04
# Epoch 69/1000
#  - 22s - loss: 4.7085e-04
# Epoch 70/1000
#  - 22s - loss: 4.7369e-04
# Epoch 71/1000
#  - 22s - loss: 4.5495e-04
# Epoch 72/1000
#  - 22s - loss: 4.1198e-04
# Epoch 73/1000
#  - 22s - loss: 3.6152e-04
# Epoch 74/1000
#  - 22s - loss: 3.2603e-04
# Epoch 75/1000
#  - 22s - loss: 3.1587e-04
# Epoch 76/1000
#  - 22s - loss: 3.2188e-04
# Epoch 77/1000
#  - 22s - loss: 3.5000e-04
# Epoch 78/1000
#  - 22s - loss: 3.8989e-04
# Epoch 79/1000
#  - 22s - loss: 3.9354e-04
# Epoch 80/1000
#  - 22s - loss: 3.5761e-04
# Epoch 81/1000
#  - 22s - loss: 3.3435e-04
# Epoch 82/1000
#  - 22s - loss: 3.4280e-04
# Epoch 83/1000
#  - 22s - loss: 0.1611
# Epoch 84/1000
#  - 22s - loss: 4.3365e-04
# Epoch 85/1000
#  - 22s - loss: 4.0945e-04
# Epoch 86/1000
#  - 22s - loss: 3.9215e-04
# Epoch 87/1000
#  - 22s - loss: 3.8595e-04
# Epoch 88/1000
#  - 22s - loss: 3.8160e-04
# Epoch 89/1000
#  - 22s - loss: 3.7371e-04
# Epoch 90/1000
#  - 22s - loss: 3.5805e-04
# Epoch 91/1000
#  - 22s - loss: 3.3227e-04
# Epoch 92/1000
#  - 22s - loss: 3.0343e-04
# Epoch 93/1000
#  - 22s - loss: 2.8828e-04
# Epoch 94/1000
#  - 22s - loss: 2.9764e-04
# Epoch 95/1000
#  - 22s - loss: 3.3412e-04
# Epoch 96/1000
#  - 22s - loss: 3.7308e-04
# Epoch 97/1000
#  - 22s - loss: 4.0139e-04
# Epoch 98/1000
#  - 22s - loss: 4.2502e-04
# Epoch 99/1000
#  - 22s - loss: 3.5462e-04
# Epoch 100/1000
#  - 22s - loss: 3.2803e-04
# Epoch 101/1000
#  - 22s - loss: 3.3476e-04
# Epoch 102/1000
#  - 22s - loss: 3.1220e-04
# Epoch 103/1000
#  - 22s - loss: 3.1075e-04
# Epoch 104/1000
#  - 22s - loss: 3.0961e-04
# Epoch 105/1000
#  - 22s - loss: 3.2693e-04
# Epoch 106/1000
#  - 22s - loss: 3.4436e-04
# Epoch 107/1000
#  - 22s - loss: 3.4487e-04
# Epoch 108/1000
#  - 22s - loss: 3.2372e-04
# Epoch 109/1000
#  - 22s - loss: 3.1103e-04
# Epoch 110/1000
#  - 22s - loss: 3.1182e-04
# Epoch 111/1000
#  - 22s - loss: 3.2939e-04
# Epoch 112/1000
#  - 22s - loss: 3.4009e-04
# Epoch 113/1000
#  - 22s - loss: 3.2762e-04
# Epoch 114/1000
#  - 22s - loss: 2.9902e-04
# Epoch 115/1000
#  - 22s - loss: 3.0404e-04
# Epoch 116/1000
#  - 22s - loss: 3.3259e-04
# Epoch 117/1000
#  - 22s - loss: 3.5385e-04
# Epoch 118/1000
#  - 22s - loss: 3.2406e-04
# Epoch 119/1000
#  - 22s - loss: 3.0564e-04
# Epoch 120/1000
#  - 22s - loss: 3.3468e-04
# Epoch 121/1000
#  - 22s - loss: 3.6256e-04
# Epoch 122/1000
#  - 22s - loss: 3.2822e-04
# Epoch 123/1000
#  - 22s - loss: 3.1757e-04
# Epoch 124/1000
#  - 22s - loss: 3.2198e-04
# Epoch 125/1000
#  - 22s - loss: 3.4929e-04
# Epoch 126/1000
#  - 22s - loss: 3.1006e-04
# Epoch 127/1000
#  - 22s - loss: 3.0072e-04
# Epoch 128/1000
#  - 22s - loss: 3.3021e-04
# Epoch 129/1000
#  - 22s - loss: 3.2216e-04
# Epoch 130/1000
#  - 22s - loss: 2.9176e-04
# Epoch 131/1000
#  - 22s - loss: 3.1008e-04
# Epoch 132/1000
#  - 22s - loss: 3.1747e-04
# Epoch 133/1000
#  - 22s - loss: 2.9247e-04
# Epoch 134/1000
#  - 22s - loss: 3.0777e-04
# Epoch 135/1000
#  - 22s - loss: 3.4264e-04
# Epoch 136/1000
#  - 22s - loss: 2.9609e-04
# Epoch 137/1000
#  - 22s - loss: 3.1868e-04
# Epoch 138/1000
#  - 22s - loss: 3.7194e-04
# Epoch 139/1000
#  - 22s - loss: 3.3865e-04
# Epoch 140/1000
#  - 22s - loss: 3.4127e-04
# Epoch 141/1000
#  - 22s - loss: 3.6006e-04
# Epoch 142/1000
#  - 22s - loss: 3.4366e-04
# Epoch 143/1000
#  - 22s - loss: 3.5889e-04
# Epoch 144/1000
#  - 22s - loss: 3.2892e-04
# Epoch 145/1000
#  - 22s - loss: 3.2461e-04
# Epoch 146/1000
#  - 22s - loss: 4.0473e-04
# Epoch 147/1000
#  - 22s - loss: 3.2497e-04
# Epoch 148/1000
#  - 22s - loss: 2.9826e-04
# Epoch 149/1000
#  - 22s - loss: 3.6102e-04
# Epoch 150/1000
#  - 22s - loss: 3.1556e-04
# Epoch 151/1000
#  - 22s - loss: 3.3417e-04
# Epoch 152/1000
#  - 22s - loss: 3.0190e-04
# Epoch 153/1000
#  - 22s - loss: 3.0559e-04
# Epoch 154/1000
#  - 22s - loss: 2.9764e-04
# Epoch 155/1000
#  - 22s - loss: 3.0519e-04
# Epoch 156/1000
#  - 22s - loss: 3.5605e-04
# Epoch 157/1000
#  - 22s - loss: 3.0693e-04
# Epoch 158/1000
#  - 22s - loss: 3.0700e-04
# Epoch 159/1000
#  - 22s - loss: 3.3260e-04
# Epoch 160/1000
#  - 22s - loss: 3.0630e-04
# Epoch 161/1000
#  - 22s - loss: 3.6208e-04
# Epoch 162/1000
#  - 22s - loss: 3.2220e-04
# Epoch 163/1000
#  - 22s - loss: 3.4987e-04
# Epoch 164/1000
#  - 22s - loss: 3.8030e-04
# Epoch 165/1000
#  - 22s - loss: 3.2026e-04
# Epoch 166/1000
#  - 22s - loss: 4.0445e-04
# Epoch 167/1000
#  - 22s - loss: 3.4279e-04
# Epoch 168/1000
#  - 22s - loss: 3.7277e-04
# Epoch 169/1000
#  - 22s - loss: 2.9718e-04
# Epoch 170/1000
#  - 22s - loss: 3.0791e-04
# Epoch 171/1000
#  - 22s - loss: 3.6627e-04
# Epoch 172/1000
#  - 22s - loss: 3.6701e-04
# Epoch 173/1000
#  - 22s - loss: 3.0701e-04
# Epoch 174/1000
#  - 22s - loss: 2.8322e-04
# Epoch 175/1000
#  - 22s - loss: 2.8980e-04
# Epoch 176/1000
#  - 22s - loss: 3.0046e-04
# Epoch 177/1000
#  - 22s - loss: 3.1008e-04
# Epoch 178/1000
#  - 22s - loss: 2.8819e-04
# Epoch 179/1000
#  - 22s - loss: 3.1736e-04
# Epoch 180/1000
#  - 22s - loss: 3.6494e-04
# Epoch 181/1000
#  - 22s - loss: 3.1756e-04
# Epoch 182/1000
#  - 22s - loss: 3.8523e-04
# Epoch 183/1000
#  - 22s - loss: 3.1044e-04
# Epoch 184/1000
#  - 22s - loss: 3.6291e-04
# Epoch 185/1000
#  - 22s - loss: 3.0720e-04
# Epoch 186/1000
#  - 22s - loss: 2.8566e-04
# Epoch 187/1000
#  - 22s - loss: 2.8743e-04
# Epoch 188/1000
#  - 22s - loss: 2.9070e-04
# Epoch 189/1000
#  - 22s - loss: 2.8479e-04
# Epoch 190/1000
#  - 22s - loss: 2.6971e-04
# Epoch 191/1000
#  - 22s - loss: 3.0825e-04
# Epoch 192/1000
#  - 22s - loss: 3.2508e-04
# Epoch 193/1000
#  - 22s - loss: 2.7675e-04
# Epoch 194/1000
#  - 22s - loss: 2.9927e-04
# Epoch 195/1000
#  - 22s - loss: 2.9449e-04
# Epoch 196/1000
#  - 22s - loss: 2.8060e-04
# Epoch 197/1000
#  - 22s - loss: 3.0445e-04
# Epoch 198/1000
#  - 22s - loss: 3.1418e-04
# Epoch 199/1000
#  - 22s - loss: 2.7719e-04
# Epoch 200/1000
#  - 22s - loss: 2.9689e-04
# Epoch 201/1000
#  - 22s - loss: 2.9541e-04
# Epoch 202/1000
#  - 22s - loss: 2.8486e-04
# Epoch 203/1000
#  - 22s - loss: 3.0736e-04
# Epoch 204/1000
#  - 22s - loss: 3.0649e-04
# Epoch 205/1000
#  - 22s - loss: 3.0068e-04
# Epoch 206/1000
#  - 22s - loss: 2.9926e-04
# Epoch 207/1000
#  - 22s - loss: 3.3783e-04
# Epoch 208/1000
#  - 22s - loss: 2.9278e-04
# Epoch 209/1000
#  - 22s - loss: 2.9630e-04
# Epoch 210/1000
#  - 22s - loss: 3.3901e-04
# Epoch 211/1000
#  - 22s - loss: 2.8099e-04
# Epoch 212/1000
#  - 22s - loss: 2.8942e-04
# Epoch 213/1000
#  - 22s - loss: 3.0774e-04
# Epoch 214/1000
#  - 22s - loss: 2.8938e-04
# Epoch 215/1000
#  - 22s - loss: 3.2014e-04
# Epoch 216/1000
#  - 22s - loss: 2.7954e-04
# Epoch 217/1000
#  - 22s - loss: 2.8114e-04
# Epoch 218/1000
#  - 22s - loss: 3.5159e-04
# Epoch 219/1000
#  - 22s - loss: 2.9037e-04
# Epoch 220/1000
#  - 22s - loss: 2.9732e-04
# Epoch 221/1000
#  - 22s - loss: 3.3308e-04
# Epoch 222/1000
#  - 22s - loss: 3.0666e-04
# Epoch 223/1000
#  - 22s - loss: 3.3110e-04
# Epoch 224/1000
#  - 22s - loss: 2.7493e-04
# Epoch 225/1000
#  - 22s - loss: 2.8473e-04
# Epoch 226/1000
#  - 22s - loss: 3.3156e-04
# Epoch 227/1000
#  - 22s - loss: 2.7441e-04
# Epoch 228/1000
#  - 22s - loss: 2.9653e-04
# Epoch 229/1000
#  - 22s - loss: 3.1175e-04
# Epoch 230/1000
#  - 22s - loss: 2.8130e-04
# Epoch 231/1000
#  - 22s - loss: 3.1762e-04
# Epoch 232/1000
#  - 22s - loss: 2.7029e-04
# Epoch 233/1000
#  - 22s - loss: 2.8838e-04
# Epoch 234/1000
#  - 22s - loss: 2.9312e-04
# Epoch 235/1000
#  - 22s - loss: 2.7364e-04
# Epoch 236/1000
#  - 22s - loss: 2.9808e-04
# Epoch 237/1000
#  - 22s - loss: 2.6979e-04
# Epoch 238/1000
#  - 22s - loss: 2.7488e-04
# Epoch 239/1000
#  - 22s - loss: 2.7843e-04
# Epoch 240/1000
#  - 22s - loss: 2.7924e-04
# Epoch 241/1000
#  - 22s - loss: 2.8021e-04
# Epoch 242/1000
#  - 22s - loss: 2.7464e-04
# Epoch 243/1000
#  - 22s - loss: 2.7621e-04
# Epoch 244/1000
#  - 22s - loss: 2.7390e-04
# Epoch 245/1000
#  - 22s - loss: 2.7001e-04
# Epoch 246/1000
#  - 22s - loss: 2.7915e-04
# Epoch 247/1000
#  - 22s - loss: 2.9853e-04
# Epoch 248/1000
#  - 22s - loss: 2.9275e-04
# Epoch 249/1000
#  - 22s - loss: 2.6659e-04
# Epoch 250/1000
#  - 22s - loss: 2.8342e-04
# Epoch 251/1000
#  - 22s - loss: 3.0117e-04
# Epoch 252/1000
#  - 22s - loss: 2.7292e-04
# Epoch 253/1000
#  - 22s - loss: 2.7119e-04
# Epoch 254/1000
#  - 22s - loss: 2.8363e-04
# Epoch 255/1000
#  - 22s - loss: 3.3455e-04
# Epoch 256/1000
#  - 22s - loss: 2.8540e-04
# Epoch 257/1000
#  - 22s - loss: 2.7583e-04
# Epoch 258/1000
#  - 22s - loss: 2.8351e-04
# Epoch 259/1000
#  - 22s - loss: 2.8829e-04
# Epoch 260/1000
#  - 22s - loss: 2.6977e-04
# Epoch 261/1000
#  - 22s - loss: 2.7616e-04
# Epoch 262/1000
#  - 22s - loss: 3.0840e-04
# Epoch 263/1000
#  - 22s - loss: 3.1824e-04
# Epoch 264/1000
#  - 22s - loss: 2.7953e-04
# Epoch 265/1000
#  - 22s - loss: 2.6534e-04
# Epoch 266/1000
#  - 22s - loss: 2.7940e-04
# Epoch 267/1000
#  - 22s - loss: 2.9722e-04
# Epoch 268/1000
#  - 22s - loss: 2.8771e-04
# Epoch 269/1000
#  - 22s - loss: 2.7031e-04
# Epoch 270/1000
#  - 22s - loss: 2.8173e-04
# Epoch 271/1000
#  - 22s - loss: 2.7658e-04
# Epoch 272/1000
#  - 22s - loss: 2.7853e-04
# Epoch 273/1000
#  - 22s - loss: 2.8080e-04
# Epoch 274/1000
#  - 22s - loss: 3.0142e-04
# Epoch 275/1000
#  - 22s - loss: 2.8888e-04
# Epoch 276/1000
#  - 22s - loss: 2.6114e-04
# Epoch 277/1000
#  - 22s - loss: 2.7991e-04
# Epoch 278/1000
#  - 22s - loss: 3.1694e-04
# Epoch 279/1000
#  - 22s - loss: 3.2117e-04
# Epoch 280/1000
#  - 22s - loss: 2.9545e-04
# Epoch 281/1000
#  - 22s - loss: 2.6395e-04
# Epoch 282/1000
#  - 22s - loss: 2.7713e-04
# Epoch 283/1000
#  - 22s - loss: 2.7655e-04
# Epoch 284/1000
#  - 22s - loss: 2.9730e-04
# Epoch 285/1000
#  - 22s - loss: 3.0064e-04
# Epoch 286/1000
#  - 22s - loss: 2.7987e-04
# Epoch 287/1000
#  - 22s - loss: 2.5973e-04
# Epoch 288/1000
#  - 22s - loss: 2.7714e-04
# Epoch 289/1000
#  - 22s - loss: 3.0701e-04
# Epoch 290/1000
#  - 22s - loss: 3.2420e-04
# Epoch 291/1000
#  - 22s - loss: 2.9755e-04
# Epoch 292/1000
#  - 22s - loss: 2.9552e-04
# Epoch 293/1000
#  - 22s - loss: 2.7868e-04
# Epoch 294/1000
#  - 22s - loss: 3.0679e-04
# Epoch 295/1000
#  - 22s - loss: 3.0574e-04
# Epoch 296/1000
#  - 22s - loss: 2.7436e-04
# Epoch 297/1000
#  - 22s - loss: 2.9050e-04
# Epoch 298/1000
#  - 22s - loss: 2.9538e-04
# Epoch 299/1000
#  - 22s - loss: 2.9544e-04
# Epoch 300/1000
#  - 22s - loss: 3.0085e-04
# Epoch 301/1000
#  - 22s - loss: 2.6360e-04
# Epoch 302/1000
#  - 22s - loss: 2.7319e-04
# Epoch 303/1000
#  - 22s - loss: 2.8037e-04
# Epoch 304/1000
#  - 22s - loss: 2.9639e-04
# Epoch 305/1000
#  - 22s - loss: 2.9687e-04
# Epoch 306/1000
#  - 22s - loss: 2.7144e-04
# Epoch 307/1000
#  - 22s - loss: 2.6625e-04
# Epoch 308/1000
#  - 22s - loss: 2.9576e-04
# Epoch 309/1000
#  - 22s - loss: 3.1167e-04
# Epoch 310/1000
#  - 22s - loss: 2.9569e-04
# Epoch 311/1000
#  - 22s - loss: 2.9270e-04
# Epoch 312/1000
#  - 22s - loss: 2.8400e-04
# Epoch 313/1000
#  - 22s - loss: 2.7134e-04
# Epoch 314/1000
#  - 22s - loss: 2.7932e-04
# Epoch 315/1000
#  - 22s - loss: 3.1698e-04
# Epoch 316/1000
#  - 22s - loss: 2.8720e-04
# Epoch 317/1000
#  - 22s - loss: 3.0842e-04
# Epoch 318/1000
#  - 22s - loss: 2.8096e-04
# Epoch 319/1000
#  - 22s - loss: 2.8526e-04
# Epoch 320/1000
#  - 22s - loss: 2.8595e-04
# Epoch 321/1000
#  - 22s - loss: 3.1814e-04
# Epoch 322/1000
#  - 22s - loss: 2.9225e-04
# Epoch 323/1000
#  - 22s - loss: 3.3997e-04
# Epoch 324/1000
#  - 22s - loss: 2.8810e-04
# Epoch 325/1000
#  - 22s - loss: 3.1270e-04
# Epoch 326/1000
#  - 22s - loss: 2.8226e-04
# Epoch 327/1000
#  - 22s - loss: 3.2554e-04
# Epoch 328/1000
#  - 22s - loss: 2.7568e-04
# Epoch 329/1000
#  - 22s - loss: 2.8726e-04
# Epoch 330/1000
#  - 22s - loss: 3.4948e-04
# Epoch 331/1000
#  - 22s - loss: 3.6581e-04
# Epoch 332/1000
#  - 22s - loss: 2.8334e-04
# Epoch 333/1000
#  - 22s - loss: 2.6351e-04
# Epoch 334/1000
#  - 22s - loss: 2.8028e-04
# Epoch 335/1000
#  - 22s - loss: 2.9386e-04
# Epoch 336/1000
#  - 22s - loss: 3.2671e-04
# Epoch 337/1000
#  - 22s - loss: 3.6519e-04
# Epoch 338/1000
#  - 22s - loss: 2.9964e-04
# Epoch 339/1000
#  - 22s - loss: 2.7560e-04
# Epoch 340/1000
#  - 22s - loss: 3.1391e-04
# Epoch 341/1000
#  - 22s - loss: 2.8019e-04
# Epoch 342/1000
#  - 22s - loss: 3.0661e-04
# Epoch 343/1000
#  - 22s - loss: 2.7178e-04
# Epoch 344/1000
#  - 22s - loss: 2.7675e-04
# Epoch 345/1000
#  - 22s - loss: 3.0777e-04
# Epoch 346/1000
#  - 22s - loss: 2.8066e-04
# Epoch 347/1000
#  - 22s - loss: 2.9709e-04
# Epoch 348/1000
#  - 22s - loss: 2.8223e-04
# Epoch 349/1000
#  - 22s - loss: 2.7974e-04
# Epoch 350/1000
#  - 22s - loss: 3.0896e-04
# Epoch 351/1000
#  - 22s - loss: 2.6980e-04
# Epoch 352/1000
#  - 22s - loss: 2.8343e-04
# Epoch 353/1000
#  - 22s - loss: 2.9339e-04
# Epoch 354/1000
#  - 22s - loss: 2.6848e-04
# Epoch 355/1000
#  - 22s - loss: 3.0103e-04
# Epoch 356/1000
#  - 22s - loss: 2.7280e-04
# Epoch 357/1000
#  - 22s - loss: 2.8887e-04
# Epoch 358/1000
#  - 22s - loss: 2.8277e-04
# Epoch 359/1000
#  - 22s - loss: 2.7242e-04
# Epoch 360/1000
#  - 22s - loss: 3.0901e-04
# Epoch 361/1000
#  - 22s - loss: 2.7700e-04
# Epoch 362/1000
#  - 23s - loss: 2.8060e-04
# Epoch 363/1000
#  - 22s - loss: 2.9656e-04
# Epoch 364/1000
#  - 22s - loss: 2.6599e-04
# Epoch 365/1000
#  - 22s - loss: 2.9589e-04
# Epoch 366/1000
#  - 22s - loss: 2.7632e-04
# Epoch 367/1000
#  - 22s - loss: 2.6780e-04
# Epoch 368/1000
#  - 22s - loss: 3.1088e-04
# Epoch 369/1000
#  - 22s - loss: 2.7056e-04
# Epoch 370/1000
#  - 22s - loss: 2.7803e-04
# Epoch 371/1000
#  - 22s - loss: 2.9296e-04
# Epoch 372/1000
#  - 22s - loss: 2.6447e-04
# Epoch 373/1000
#  - 22s - loss: 2.9570e-04
# Epoch 374/1000
#  - 22s - loss: 2.8062e-04
# Epoch 375/1000
#  - 22s - loss: 2.6207e-04
# Epoch 376/1000
#  - 22s - loss: 3.0136e-04
# Epoch 377/1000
#  - 22s - loss: 2.7482e-04
# Epoch 378/1000
#  - 22s - loss: 2.6182e-04
# Epoch 379/1000
#  - 22s - loss: 2.9762e-04
# Epoch 380/1000
#  - 22s - loss: 2.6854e-04
# Epoch 381/1000
#  - 22s - loss: 2.6148e-04
# Epoch 382/1000
#  - 22s - loss: 2.9654e-04
# Epoch 383/1000
#  - 22s - loss: 2.6766e-04
# Epoch 384/1000
#  - 22s - loss: 2.6124e-04
# Epoch 385/1000
#  - 22s - loss: 2.9453e-04
# Epoch 386/1000
#  - 22s - loss: 2.7234e-04
# Epoch 387/1000
#  - 22s - loss: 2.5995e-04
# Epoch 388/1000
#  - 22s - loss: 2.8633e-04
# Epoch 389/1000
#  - 22s - loss: 2.8311e-04
# Epoch 390/1000
#  - 22s - loss: 2.5793e-04
# Epoch 391/1000
#  - 22s - loss: 2.7473e-04
# Epoch 392/1000
#  - 22s - loss: 2.9599e-04
# Epoch 393/1000
#  - 22s - loss: 2.5846e-04
# Epoch 394/1000
#  - 22s - loss: 2.6554e-04
# Epoch 395/1000
#  - 22s - loss: 2.9606e-04
# Epoch 396/1000
#  - 22s - loss: 2.6982e-04
# Epoch 397/1000
#  - 22s - loss: 2.6114e-04
# Epoch 398/1000
#  - 22s - loss: 2.8612e-04
# Epoch 399/1000
#  - 22s - loss: 2.7920e-04
# Epoch 400/1000
#  - 22s - loss: 2.5936e-04
# Epoch 401/1000
#  - 22s - loss: 2.8244e-04
# Epoch 402/1000
#  - 22s - loss: 2.9051e-04
# Epoch 403/1000
#  - 22s - loss: 2.5913e-04
# Epoch 404/1000
#  - 22s - loss: 2.7243e-04
# Epoch 405/1000
#  - 22s - loss: 2.9143e-04
# Epoch 406/1000
#  - 22s - loss: 2.6042e-04
# Epoch 407/1000
#  - 22s - loss: 2.6600e-04
# Epoch 408/1000
#  - 22s - loss: 2.9227e-04
# Epoch 409/1000
#  - 22s - loss: 2.6437e-04
# Epoch 410/1000
#  - 22s - loss: 2.6151e-04
# Epoch 411/1000
#  - 22s - loss: 2.9004e-04
# Epoch 412/1000
#  - 22s - loss: 2.7453e-04
# Epoch 413/1000
#  - 22s - loss: 2.5872e-04
# Epoch 414/1000
#  - 22s - loss: 2.8044e-04
# Epoch 415/1000
#  - 22s - loss: 2.8668e-04
# Epoch 416/1000
#  - 22s - loss: 2.5676e-04
# Epoch 417/1000
#  - 22s - loss: 2.6751e-04
# Epoch 418/1000
#  - 22s - loss: 2.9196e-04
# Epoch 419/1000
#  - 22s - loss: 2.6066e-04
# Epoch 420/1000
#  - 22s - loss: 2.6067e-04
# Epoch 421/1000
#  - 22s - loss: 2.8952e-04
# Epoch 422/1000
#  - 22s - loss: 2.7812e-04
# Epoch 423/1000
#  - 22s - loss: 2.5658e-04
# Epoch 424/1000
#  - 22s - loss: 2.7268e-04
# Epoch 425/1000
#  - 22s - loss: 2.9514e-04
# Epoch 426/1000
#  - 22s - loss: 2.5876e-04
# Epoch 427/1000
#  - 22s - loss: 2.6386e-04
# Epoch 428/1000
#  - 22s - loss: 2.9274e-04
# Epoch 429/1000
#  - 22s - loss: 2.7139e-04
# Epoch 430/1000
#  - 22s - loss: 2.5902e-04
# Epoch 431/1000
#  - 22s - loss: 2.7723e-04
# Epoch 432/1000
#  - 22s - loss: 2.8565e-04
# Epoch 433/1000
#  - 22s - loss: 2.5628e-04
# Epoch 434/1000
#  - 22s - loss: 2.7162e-04
# Epoch 435/1000
#  - 22s - loss: 2.9371e-04
# Epoch 436/1000
#  - 22s - loss: 2.6251e-04
# Epoch 437/1000
#  - 22s - loss: 2.6800e-04
# Epoch 438/1000
#  - 22s - loss: 2.9216e-04
# Epoch 439/1000
#  - 22s - loss: 2.7124e-04
# Epoch 440/1000
#  - 22s - loss: 2.6093e-04
# Epoch 441/1000
#  - 22s - loss: 2.8972e-04
# Epoch 442/1000
#  - 22s - loss: 2.7763e-04
# Epoch 443/1000
#  - 22s - loss: 2.5962e-04
# Epoch 444/1000
#  - 22s - loss: 2.8653e-04
# Epoch 445/1000
#  - 22s - loss: 2.8117e-04
# Epoch 446/1000
#  - 22s - loss: 2.5932e-04
# Epoch 447/1000
#  - 22s - loss: 2.7925e-04
# Epoch 448/1000
#  - 22s - loss: 2.8267e-04
# Epoch 449/1000
#  - 22s - loss: 2.5610e-04
# Epoch 450/1000
#  - 22s - loss: 2.7026e-04
# Epoch 451/1000
#  - 22s - loss: 2.8291e-04
# Epoch 452/1000
#  - 22s - loss: 2.5640e-04
# Epoch 453/1000
#  - 22s - loss: 2.6292e-04
# Epoch 454/1000
#  - 22s - loss: 2.8108e-04
# Epoch 455/1000
#  - 22s - loss: 2.6338e-04
# Epoch 456/1000
#  - 22s - loss: 2.5740e-04
# Epoch 457/1000
#  - 22s - loss: 2.7128e-04
# Epoch 458/1000
#  - 22s - loss: 2.7264e-04
# Epoch 459/1000
#  - 22s - loss: 2.5867e-04
# Epoch 460/1000
#  - 22s - loss: 2.6413e-04
# Epoch 461/1000
#  - 22s - loss: 2.7327e-04
# Epoch 462/1000
#  - 22s - loss: 2.6662e-04
# Epoch 463/1000
#  - 22s - loss: 2.5849e-04
# Epoch 464/1000
#  - 22s - loss: 2.6329e-04
# Epoch 465/1000
#  - 22s - loss: 2.6860e-04
# Epoch 466/1000
#  - 22s - loss: 2.6416e-04
# Epoch 467/1000
#  - 22s - loss: 2.6051e-04
# Epoch 468/1000
#  - 22s - loss: 2.6463e-04
# Epoch 469/1000
#  - 22s - loss: 2.7288e-04
# Epoch 470/1000
#  - 22s - loss: 2.7228e-04
# Epoch 471/1000
#  - 22s - loss: 2.8589e-04
# Epoch 472/1000
#  - 22s - loss: 2.8944e-04
# Epoch 473/1000
#  - 22s - loss: 2.5813e-04
# Epoch 474/1000
#  - 22s - loss: 2.6883e-04
# Epoch 475/1000
#  - 22s - loss: 2.7564e-04
# Epoch 476/1000
#  - 22s - loss: 2.6248e-04
# Epoch 477/1000
#  - 22s - loss: 2.6674e-04
# Epoch 478/1000
#  - 22s - loss: 2.7763e-04
# Epoch 479/1000
#  - 22s - loss: 2.5921e-04
# Epoch 480/1000
#  - 22s - loss: 2.7418e-04
# Epoch 481/1000
#  - 22s - loss: 2.8049e-04
# Epoch 482/1000
#  - 22s - loss: 2.6093e-04
# Epoch 483/1000
#  - 22s - loss: 2.7164e-04
# Epoch 484/1000
#  - 22s - loss: 2.7896e-04
# Epoch 485/1000
#  - 22s - loss: 2.5928e-04
# Epoch 486/1000
#  - 22s - loss: 2.7335e-04
# Epoch 487/1000
#  - 22s - loss: 2.7979e-04
# Epoch 488/1000
#  - 22s - loss: 2.5731e-04
# Epoch 489/1000
#  - 22s - loss: 2.7942e-04
# Epoch 490/1000
#  - 22s - loss: 2.7847e-04
# Epoch 491/1000
#  - 22s - loss: 2.6200e-04
# Epoch 492/1000
#  - 22s - loss: 2.7389e-04
# Epoch 493/1000
#  - 22s - loss: 2.7290e-04
# Epoch 494/1000
#  - 22s - loss: 2.6045e-04
# Epoch 495/1000
#  - 22s - loss: 2.7337e-04
# Epoch 496/1000
#  - 22s - loss: 2.6738e-04
# Epoch 497/1000
#  - 22s - loss: 2.7021e-04
# Epoch 498/1000
#  - 22s - loss: 2.7646e-04
# Epoch 499/1000
#  - 22s - loss: 2.6628e-04
# Epoch 500/1000
#  - 22s - loss: 2.7385e-04
# Epoch 501/1000
#  - 22s - loss: 2.6813e-04
# Epoch 502/1000
#  - 22s - loss: 2.6108e-04
# Epoch 503/1000
#  - 22s - loss: 2.7531e-04
# Epoch 504/1000
#  - 22s - loss: 2.8486e-04
# Epoch 505/1000
#  - 22s - loss: 2.6311e-04
# Epoch 506/1000
#  - 22s - loss: 2.7365e-04
# Epoch 507/1000
#  - 22s - loss: 2.8007e-04
# Epoch 508/1000
#  - 22s - loss: 2.6090e-04
# Epoch 509/1000
#  - 22s - loss: 2.7960e-04
# Epoch 510/1000
#  - 22s - loss: 2.8271e-04
# Epoch 511/1000
#  - 22s - loss: 2.6351e-04
# Epoch 512/1000
#  - 22s - loss: 2.7783e-04
# Epoch 513/1000
#  - 22s - loss: 2.7867e-04
# Epoch 514/1000
#  - 22s - loss: 2.6714e-04
# Epoch 515/1000
#  - 22s - loss: 2.7752e-04
# Epoch 516/1000
#  - 22s - loss: 2.7470e-04
# Epoch 517/1000
#  - 22s - loss: 2.6879e-04
# Epoch 518/1000
#  - 22s - loss: 2.7512e-04
# Epoch 519/1000
#  - 22s - loss: 2.7093e-04
# Epoch 520/1000
#  - 22s - loss: 2.7202e-04
# Epoch 521/1000
#  - 22s - loss: 2.7450e-04
# Epoch 522/1000
#  - 22s - loss: 2.6788e-04
# Epoch 523/1000
#  - 22s - loss: 2.7435e-04
# Epoch 524/1000
#  - 22s - loss: 2.7345e-04
# Epoch 525/1000
#  - 22s - loss: 2.6493e-04
# Epoch 526/1000
#  - 22s - loss: 2.7365e-04
# Epoch 527/1000
#  - 22s - loss: 2.7123e-04
# Epoch 528/1000
#  - 22s - loss: 2.6255e-04
# Epoch 529/1000
#  - 22s - loss: 2.6991e-04
# Epoch 530/1000
#  - 22s - loss: 2.6747e-04
# Epoch 531/1000
#  - 22s - loss: 2.6056e-04
# Epoch 532/1000
#  - 22s - loss: 2.6538e-04
# Epoch 533/1000
#  - 22s - loss: 2.6359e-04
# Epoch 534/1000
#  - 22s - loss: 2.6076e-04
# Epoch 535/1000
#  - 22s - loss: 2.6287e-04
# Epoch 536/1000
#  - 22s - loss: 2.6115e-04
# Epoch 537/1000
#  - 22s - loss: 2.6473e-04
# Epoch 538/1000
#  - 22s - loss: 2.6307e-04
# Epoch 539/1000
#  - 22s - loss: 2.6451e-04
# Epoch 540/1000
#  - 22s - loss: 2.6523e-04
# Epoch 541/1000
#  - 22s - loss: 2.6586e-04
# Epoch 542/1000
#  - 22s - loss: 2.6383e-04
# Epoch 543/1000
#  - 22s - loss: 2.6785e-04
# Epoch 544/1000
#  - 22s - loss: 2.6648e-04
# Epoch 545/1000
#  - 22s - loss: 2.5518e-04
# Epoch 546/1000
#  - 22s - loss: 2.6088e-04
# Epoch 547/1000
#  - 22s - loss: 2.6078e-04
# Epoch 548/1000
#  - 22s - loss: 2.6524e-04
# Epoch 549/1000
#  - 22s - loss: 2.6711e-04
# Epoch 550/1000
#  - 22s - loss: 2.6677e-04
# Epoch 551/1000
#  - 22s - loss: 2.6159e-04
# Epoch 552/1000
#  - 22s - loss: 2.6379e-04
# Epoch 553/1000
#  - 22s - loss: 2.5878e-04
# Epoch 554/1000
#  - 22s - loss: 2.5821e-04
# Epoch 555/1000
#  - 22s - loss: 2.5645e-04
# Epoch 556/1000
#  - 22s - loss: 2.6696e-04
# Epoch 557/1000
#  - 22s - loss: 2.7160e-04
# Epoch 558/1000
#  - 22s - loss: 2.7016e-04
# Epoch 559/1000
#  - 22s - loss: 2.6507e-04
# Epoch 560/1000
#  - 22s - loss: 2.5832e-04
# Epoch 561/1000
#  - 22s - loss: 2.5938e-04
# Epoch 562/1000
#  - 22s - loss: 2.5401e-04
# Epoch 563/1000
#  - 22s - loss: 2.6321e-04
# Epoch 564/1000
#  - 22s - loss: 2.7333e-04
# Epoch 565/1000
#  - 22s - loss: 2.7311e-04
# Epoch 566/1000
#  - 22s - loss: 2.6734e-04
# Epoch 567/1000
#  - 22s - loss: 2.6005e-04
# Epoch 568/1000
#  - 22s - loss: 2.5613e-04
# Epoch 569/1000
#  - 22s - loss: 2.5434e-04
# Epoch 570/1000
#  - 22s - loss: 2.6398e-04
# Epoch 571/1000
#  - 22s - loss: 2.7511e-04
# Epoch 572/1000
#  - 22s - loss: 2.7065e-04
# Epoch 573/1000
#  - 22s - loss: 2.6461e-04
# Epoch 574/1000
#  - 22s - loss: 2.5919e-04
# Epoch 575/1000
#  - 22s - loss: 2.5188e-04
# Epoch 576/1000
#  - 22s - loss: 2.5600e-04
# Epoch 577/1000
#  - 22s - loss: 2.6070e-04
# Epoch 578/1000
#  - 22s - loss: 2.7149e-04
# Epoch 579/1000
#  - 22s - loss: 2.7366e-04
# Epoch 580/1000
#  - 22s - loss: 2.6560e-04
# Epoch 581/1000
#  - 22s - loss: 2.5367e-04
# Epoch 582/1000
#  - 22s - loss: 2.5649e-04
# Epoch 583/1000
#  - 22s - loss: 2.5367e-04
# Epoch 584/1000
#  - 22s - loss: 2.6743e-04
# Epoch 585/1000
#  - 22s - loss: 2.6485e-04
# Epoch 586/1000
#  - 22s - loss: 2.7563e-04
# Epoch 587/1000
#  - 22s - loss: 2.6518e-04
# Epoch 588/1000
#  - 22s - loss: 2.6943e-04
# Epoch 589/1000
#  - 22s - loss: 2.5871e-04
# Epoch 590/1000
#  - 22s - loss: 2.6134e-04
# Epoch 591/1000
#  - 22s - loss: 2.6129e-04
# Epoch 592/1000
#  - 22s - loss: 2.6182e-04
# Epoch 593/1000
#  - 22s - loss: 2.6232e-04
# Epoch 594/1000
#  - 22s - loss: 2.7223e-04
# Epoch 595/1000
#  - 22s - loss: 2.6246e-04
# Epoch 596/1000
#  - 22s - loss: 2.7462e-04
# Epoch 597/1000
#  - 22s - loss: 2.6177e-04
# Epoch 598/1000
#  - 22s - loss: 2.7433e-04
# Epoch 599/1000
#  - 22s - loss: 2.6323e-04
# Epoch 600/1000
#  - 22s - loss: 2.6538e-04
# Epoch 601/1000
#  - 22s - loss: 2.6095e-04
# Epoch 602/1000
#  - 22s - loss: 2.6213e-04
# Epoch 603/1000
#  - 22s - loss: 2.5964e-04
# Epoch 604/1000
#  - 22s - loss: 2.6968e-04
# Epoch 605/1000
#  - 22s - loss: 2.6037e-04
# Epoch 606/1000
#  - 22s - loss: 2.7480e-04
# Epoch 607/1000
#  - 22s - loss: 2.6021e-04
# Epoch 608/1000
#  - 22s - loss: 2.7626e-04
# Epoch 609/1000
#  - 22s - loss: 2.5977e-04
# Epoch 610/1000
#  - 22s - loss: 2.7000e-04
# Epoch 611/1000
#  - 22s - loss: 2.5739e-04
# Epoch 612/1000
#  - 22s - loss: 2.6698e-04
# Epoch 613/1000
#  - 22s - loss: 2.5804e-04
# Epoch 614/1000
#  - 22s - loss: 2.6794e-04
# Epoch 615/1000
#  - 22s - loss: 2.5915e-04
# Epoch 616/1000
#  - 22s - loss: 2.6841e-04
# Epoch 617/1000
#  - 22s - loss: 2.5816e-04
# Epoch 618/1000
#  - 22s - loss: 2.6783e-04
# Epoch 619/1000
#  - 22s - loss: 2.5644e-04
# Epoch 620/1000
#  - 22s - loss: 2.6670e-04
# Epoch 621/1000
#  - 22s - loss: 2.5656e-04
# Epoch 622/1000
#  - 22s - loss: 2.6629e-04
# Epoch 623/1000
#  - 22s - loss: 2.5771e-04
# Epoch 624/1000
#  - 22s - loss: 2.6575e-04
# Epoch 625/1000
#  - 22s - loss: 2.5810e-04
# Epoch 626/1000
#  - 22s - loss: 2.6537e-04
# Epoch 627/1000
#  - 22s - loss: 2.5820e-04
# Epoch 628/1000
#  - 22s - loss: 2.6523e-04
# Epoch 629/1000
#  - 22s - loss: 2.5839e-04
# Epoch 630/1000
#  - 22s - loss: 2.6518e-04
# Epoch 631/1000
#  - 22s - loss: 2.5865e-04
# Epoch 632/1000
#  - 22s - loss: 2.6500e-04
# Epoch 633/1000
#  - 22s - loss: 2.5877e-04
# Epoch 634/1000
#  - 22s - loss: 2.6506e-04
# Epoch 635/1000
#  - 22s - loss: 2.5914e-04
# Epoch 636/1000
#  - 22s - loss: 2.6536e-04
# Epoch 637/1000
#  - 22s - loss: 2.5961e-04
# Epoch 638/1000
#  - 22s - loss: 2.6529e-04
# Epoch 639/1000
#  - 22s - loss: 2.5973e-04
# Epoch 640/1000
#  - 22s - loss: 2.6482e-04
# Epoch 641/1000
#  - 22s - loss: 2.5958e-04
# Epoch 642/1000
#  - 22s - loss: 2.6482e-04
# Epoch 643/1000
#  - 22s - loss: 2.5976e-04
# Epoch 644/1000
#  - 22s - loss: 2.6522e-04
# Epoch 645/1000
#  - 22s - loss: 2.6003e-04
# Epoch 646/1000
#  - 22s - loss: 2.6483e-04
# Epoch 647/1000
#  - 22s - loss: 2.5970e-04
# Epoch 648/1000
#  - 22s - loss: 2.6395e-04
# Epoch 649/1000
#  - 22s - loss: 2.5931e-04
# Epoch 650/1000
#  - 22s - loss: 2.6467e-04
# Epoch 651/1000
#  - 22s - loss: 2.5992e-04
# Epoch 652/1000
#  - 22s - loss: 2.6538e-04
# Epoch 653/1000
#  - 22s - loss: 2.6026e-04
# Epoch 654/1000
#  - 22s - loss: 2.6385e-04
# Epoch 655/1000
#  - 22s - loss: 2.5926e-04
# Epoch 656/1000
#  - 22s - loss: 2.6225e-04
# Epoch 657/1000
#  - 22s - loss: 2.5903e-04
# Epoch 658/1000
#  - 22s - loss: 2.6536e-04
# Epoch 659/1000
#  - 22s - loss: 2.6091e-04
# Epoch 660/1000
#  - 22s - loss: 2.6591e-04
# Epoch 661/1000
#  - 22s - loss: 2.6074e-04
# Epoch 662/1000
#  - 22s - loss: 2.5950e-04
# Epoch 663/1000
#  - 22s - loss: 2.5742e-04
# Epoch 664/1000
#  - 22s - loss: 2.6275e-04
# Epoch 665/1000
#  - 22s - loss: 2.5894e-04
# Epoch 666/1000
#  - 22s - loss: 2.6964e-04
# Epoch 667/1000
#  - 22s - loss: 2.6598e-04
# Epoch 668/1000
#  - 22s - loss: 2.6755e-04
# Epoch 669/1000
#  - 22s - loss: 2.6783e-04
# Epoch 670/1000
#  - 22s - loss: 2.5908e-04
# Epoch 671/1000
#  - 22s - loss: 2.6607e-04
# Epoch 672/1000
#  - 22s - loss: 2.6950e-04
# Epoch 673/1000
#  - 22s - loss: 2.6560e-04
# Epoch 674/1000
#  - 22s - loss: 2.6416e-04
# Epoch 675/1000
#  - 22s - loss: 2.7520e-04
# Epoch 676/1000
#  - 22s - loss: 2.7654e-04
# Epoch 677/1000
#  - 22s - loss: 2.5987e-04
# Epoch 678/1000
#  - 22s - loss: 2.6348e-04
# Epoch 679/1000
#  - 22s - loss: 2.6967e-04
# Epoch 680/1000
#  - 22s - loss: 2.6561e-04
# Epoch 681/1000
#  - 22s - loss: 2.6410e-04
# Epoch 682/1000
#  - 22s - loss: 2.6745e-04
# Epoch 683/1000
#  - 22s - loss: 2.5887e-04
# Epoch 684/1000
#  - 22s - loss: 2.6006e-04
# Epoch 685/1000
#  - 22s - loss: 2.6781e-04
# Epoch 686/1000
#  - 22s - loss: 2.6126e-04
# Epoch 687/1000
#  - 22s - loss: 2.5743e-04
# Epoch 688/1000
#  - 22s - loss: 2.6604e-04
# Epoch 689/1000
#  - 22s - loss: 2.5452e-04
# Epoch 690/1000
#  - 22s - loss: 2.6421e-04
# Epoch 691/1000
#  - 22s - loss: 2.6504e-04
# Epoch 692/1000
#  - 22s - loss: 2.5556e-04
# Epoch 693/1000
#  - 22s - loss: 2.6063e-04
# Epoch 694/1000
#  - 22s - loss: 2.5435e-04
# Epoch 695/1000
#  - 22s - loss: 2.6269e-04
# Epoch 696/1000
#  - 22s - loss: 2.6380e-04
# Epoch 697/1000
#  - 22s - loss: 2.5581e-04
# Epoch 698/1000
#  - 22s - loss: 2.6157e-04
# Epoch 699/1000
#  - 22s - loss: 2.5561e-04
# Epoch 700/1000
#  - 22s - loss: 2.6194e-04
# Epoch 701/1000
#  - 22s - loss: 2.5716e-04
# Epoch 702/1000
#  - 22s - loss: 2.5711e-04
# Epoch 703/1000
#  - 22s - loss: 2.5778e-04
# Epoch 704/1000
#  - 22s - loss: 2.5842e-04
# Epoch 705/1000
#  - 22s - loss: 2.6257e-04
# Epoch 706/1000
#  - 22s - loss: 2.5303e-04
# Epoch 707/1000
#  - 22s - loss: 2.5438e-04
# Epoch 708/1000
#  - 22s - loss: 2.5753e-04
# Epoch 709/1000
#  - 22s - loss: 2.6279e-04
# Epoch 710/1000
#  - 22s - loss: 2.5697e-04
# Epoch 711/1000
#  - 22s - loss: 2.5387e-04
# Epoch 712/1000
#  - 22s - loss: 2.5222e-04
# Epoch 713/1000
#  - 22s - loss: 2.6223e-04
# Epoch 714/1000
#  - 22s - loss: 2.6754e-04
# Epoch 715/1000
#  - 22s - loss: 2.5110e-04
# Epoch 716/1000
#  - 22s - loss: 2.5574e-04
# Epoch 717/1000
#  - 22s - loss: 2.5145e-04
# Epoch 718/1000
#  - 22s - loss: 2.6308e-04
# Epoch 719/1000
#  - 22s - loss: 2.5558e-04
# Epoch 720/1000
#  - 22s - loss: 2.5852e-04
# Epoch 721/1000
#  - 22s - loss: 2.5235e-04
# Epoch 722/1000
#  - 22s - loss: 2.5605e-04
# Epoch 723/1000
#  - 22s - loss: 2.5056e-04
# Epoch 724/1000
#  - 22s - loss: 2.5990e-04
# Epoch 725/1000
#  - 22s - loss: 2.5566e-04
# Epoch 726/1000
#  - 22s - loss: 2.5978e-04
# Epoch 727/1000
#  - 22s - loss: 2.5234e-04
# Epoch 728/1000
#  - 22s - loss: 2.5820e-04
# Epoch 729/1000
#  - 22s - loss: 2.5124e-04
# Epoch 730/1000
#  - 22s - loss: 2.6505e-04
# Epoch 731/1000
#  - 22s - loss: 2.5857e-04
# Epoch 732/1000
#  - 22s - loss: 2.5835e-04
# Epoch 733/1000
#  - 22s - loss: 2.5117e-04
# Epoch 734/1000
#  - 22s - loss: 2.5130e-04
# Epoch 735/1000
#  - 22s - loss: 2.4878e-04
# Epoch 736/1000
#  - 22s - loss: 2.5885e-04
# Epoch 737/1000
#  - 22s - loss: 2.6425e-04
# Epoch 738/1000
#  - 22s - loss: 2.6518e-04
# Epoch 739/1000
#  - 22s - loss: 2.5295e-04
# Epoch 740/1000
#  - 22s - loss: 2.5137e-04
# Epoch 741/1000
#  - 22s - loss: 2.4915e-04
# Epoch 742/1000
#  - 22s - loss: 2.6565e-04
# Epoch 743/1000
#  - 22s - loss: 2.7009e-04
# Epoch 744/1000
#  - 22s - loss: 2.5188e-04
# Epoch 745/1000
#  - 22s - loss: 2.4662e-04
# Epoch 746/1000
#  - 22s - loss: 2.5181e-04
# Epoch 747/1000
#  - 22s - loss: 2.5210e-04
# Epoch 748/1000
#  - 22s - loss: 2.6349e-04
# Epoch 749/1000
#  - 22s - loss: 2.5634e-04
# Epoch 750/1000
#  - 22s - loss: 2.5500e-04
# Epoch 751/1000
#  - 22s - loss: 2.4804e-04
# Epoch 752/1000
#  - 22s - loss: 2.4963e-04
# Epoch 753/1000
#  - 22s - loss: 2.4896e-04
# Epoch 754/1000
#  - 22s - loss: 2.5790e-04
# Epoch 755/1000
#  - 22s - loss: 2.5580e-04
# Epoch 756/1000
#  - 22s - loss: 2.5076e-04
# Epoch 757/1000
#  - 22s - loss: 2.5176e-04
# Epoch 758/1000
#  - 22s - loss: 2.5536e-04
# Epoch 759/1000
#  - 22s - loss: 2.7536e-04
# Epoch 760/1000
#  - 22s - loss: 2.6815e-04
# Epoch 761/1000
#  - 22s - loss: 2.4978e-04
# Epoch 762/1000
#  - 22s - loss: 2.6189e-04
# Epoch 763/1000
#  - 22s - loss: 2.5313e-04
# Epoch 764/1000
#  - 22s - loss: 2.5787e-04
# Epoch 765/1000
#  - 22s - loss: 2.5284e-04
# Epoch 766/1000
#  - 22s - loss: 2.4935e-04
# Epoch 767/1000
#  - 22s - loss: 2.5191e-04
# Epoch 768/1000
#  - 22s - loss: 2.5870e-04
# Epoch 769/1000
#  - 22s - loss: 2.6110e-04
# Epoch 770/1000
#  - 22s - loss: 2.6624e-04
# Epoch 771/1000
#  - 22s - loss: 2.6635e-04
# Epoch 772/1000
#  - 22s - loss: 2.7095e-04
# Epoch 773/1000
#  - 22s - loss: 2.4822e-04
# Epoch 774/1000
#  - 22s - loss: 2.4925e-04
# Epoch 775/1000
#  - 22s - loss: 2.4840e-04
# Epoch 776/1000
#  - 22s - loss: 2.5686e-04
# Epoch 777/1000
#  - 22s - loss: 2.6337e-04
# Epoch 778/1000
#  - 22s - loss: 2.7121e-04
# Epoch 779/1000
#  - 22s - loss: 2.8014e-04
# Epoch 780/1000
#  - 22s - loss: 2.7621e-04
# Epoch 781/1000
#  - 22s - loss: 2.5478e-04
# Epoch 782/1000
#  - 22s - loss: 2.4496e-04
# Epoch 783/1000
#  - 22s - loss: 2.4173e-04
# Epoch 784/1000
#  - 22s - loss: 2.5598e-04
# Epoch 785/1000
#  - 22s - loss: 2.6271e-04
# Epoch 786/1000
#  - 22s - loss: 2.5743e-04
# Epoch 787/1000
#  - 22s - loss: 2.6725e-04
# Epoch 788/1000
#  - 22s - loss: 2.7357e-04
# Epoch 789/1000
#  - 22s - loss: 2.6627e-04
# Epoch 790/1000
#  - 22s - loss: 2.5694e-04
# Epoch 791/1000
#  - 22s - loss: 2.4915e-04
# Epoch 792/1000
#  - 22s - loss: 2.4553e-04
# Epoch 793/1000
#  - 22s - loss: 2.4617e-04
# Epoch 794/1000
#  - 22s - loss: 2.4763e-04
# Epoch 795/1000
#  - 22s - loss: 2.5066e-04
# Epoch 796/1000
#  - 22s - loss: 2.5727e-04
# Epoch 797/1000
#  - 22s - loss: 2.6673e-04
# Epoch 798/1000
#  - 22s - loss: 2.6534e-04
# Epoch 799/1000
#  - 22s - loss: 2.6862e-04
# Epoch 800/1000
#  - 22s - loss: 2.7179e-04
# Epoch 801/1000
#  - 22s - loss: 2.5706e-04
# Epoch 802/1000
#  - 22s - loss: 2.5333e-04
# Epoch 803/1000
#  - 22s - loss: 2.4172e-04
# Epoch 804/1000
#  - 22s - loss: 2.5278e-04
# Epoch 805/1000
#  - 22s - loss: 2.5273e-04
# Epoch 806/1000
#  - 22s - loss: 2.6125e-04
# Epoch 807/1000
#  - 22s - loss: 2.5307e-04
# Epoch 808/1000
#  - 22s - loss: 2.6073e-04
# Epoch 809/1000
#  - 22s - loss: 2.4747e-04
# Epoch 810/1000
#  - 22s - loss: 2.5840e-04
# Epoch 811/1000
#  - 22s - loss: 2.4937e-04
# Epoch 812/1000
#  - 22s - loss: 2.6046e-04
# Epoch 813/1000
#  - 22s - loss: 2.5024e-04
# Epoch 814/1000
#  - 22s - loss: 2.5706e-04
# Epoch 815/1000
#  - 22s - loss: 2.4709e-04
# Epoch 816/1000
#  - 22s - loss: 2.5909e-04
# Epoch 817/1000
#  - 22s - loss: 2.4945e-04
# Epoch 818/1000
#  - 22s - loss: 2.5811e-04
# Epoch 819/1000
#  - 22s - loss: 2.4750e-04
# Epoch 820/1000
#  - 22s - loss: 2.6022e-04
# Epoch 821/1000
#  - 22s - loss: 2.5001e-04
# Epoch 822/1000
#  - 22s - loss: 2.5800e-04
# Epoch 823/1000
#  - 22s - loss: 2.4708e-04
# Epoch 824/1000
#  - 22s - loss: 2.6095e-04
# Epoch 825/1000
#  - 22s - loss: 2.5036e-04
# Epoch 826/1000
#  - 22s - loss: 2.5604e-04
# Epoch 827/1000
#  - 22s - loss: 2.4589e-04
# Epoch 828/1000
#  - 22s - loss: 2.6037e-04
# Epoch 829/1000
#  - 22s - loss: 2.5060e-04
# Epoch 830/1000
#  - 22s - loss: 2.5429e-04
# Epoch 831/1000
#  - 22s - loss: 2.4510e-04
# Epoch 832/1000
#  - 22s - loss: 2.6045e-04
# Epoch 833/1000
#  - 22s - loss: 2.5135e-04
# Epoch 834/1000
#  - 22s - loss: 2.5345e-04
# Epoch 835/1000
#  - 22s - loss: 2.4483e-04
# Epoch 836/1000
#  - 22s - loss: 2.6073e-04
# Epoch 837/1000
#  - 22s - loss: 2.5187e-04
# Epoch 838/1000
#  - 22s - loss: 2.5324e-04
# Epoch 839/1000
#  - 22s - loss: 2.4461e-04
# Epoch 840/1000
#  - 22s - loss: 2.6032e-04
# Epoch 841/1000
#  - 22s - loss: 2.5206e-04
# Epoch 842/1000
#  - 22s - loss: 2.5323e-04
# Epoch 843/1000
#  - 22s - loss: 2.4452e-04
# Epoch 844/1000
#  - 22s - loss: 2.5791e-04
# Epoch 845/1000
#  - 22s - loss: 2.5002e-04
# Epoch 846/1000
#  - 22s - loss: 2.5606e-04
# Epoch 847/1000
#  - 22s - loss: 2.4616e-04
# Epoch 848/1000
#  - 22s - loss: 2.5574e-04
# Epoch 849/1000
#  - 22s - loss: 2.4742e-04
# Epoch 850/1000
#  - 22s - loss: 2.5780e-04
# Epoch 851/1000
#  - 22s - loss: 2.4828e-04
# Epoch 852/1000
#  - 22s - loss: 2.5152e-04
# Epoch 853/1000
#  - 22s - loss: 2.4555e-04
# Epoch 854/1000
#  - 22s - loss: 2.5747e-04
# Epoch 855/1000
#  - 22s - loss: 2.4952e-04
# Epoch 856/1000
#  - 22s - loss: 2.5517e-04
# Epoch 857/1000
#  - 22s - loss: 2.4502e-04
# Epoch 858/1000
#  - 22s - loss: 2.5262e-04
# Epoch 859/1000
#  - 22s - loss: 2.4635e-04
# Epoch 860/1000
#  - 22s - loss: 2.6471e-04
# Epoch 861/1000
#  - 22s - loss: 2.5596e-04
# Epoch 862/1000
#  - 22s - loss: 2.4331e-04
# Epoch 863/1000
#  - 22s - loss: 2.4515e-04
# Epoch 864/1000
#  - 22s - loss: 2.5075e-04
# Epoch 865/1000
#  - 22s - loss: 2.5033e-04
# Epoch 866/1000
#  - 22s - loss: 2.5146e-04
# Epoch 867/1000
#  - 22s - loss: 2.5785e-04
# Epoch 868/1000
#  - 22s - loss: 2.6902e-04
# Epoch 869/1000
#  - 22s - loss: 2.5417e-04
# Epoch 870/1000
#  - 22s - loss: 2.4508e-04
# Epoch 871/1000
#  - 22s - loss: 2.4177e-04
# Epoch 872/1000
#  - 22s - loss: 2.4834e-04
# Epoch 873/1000
#  - 22s - loss: 2.5352e-04
# Epoch 874/1000
#  - 22s - loss: 2.5127e-04
# Epoch 875/1000
#  - 22s - loss: 2.6569e-04
# Epoch 876/1000
#  - 22s - loss: 2.7057e-04
# Epoch 877/1000
#  - 22s - loss: 2.5704e-04
# Epoch 878/1000
#  - 22s - loss: 2.4384e-04
# Epoch 879/1000
#  - 22s - loss: 2.4375e-04
# Epoch 880/1000
#  - 22s - loss: 2.4291e-04
# Epoch 881/1000
#  - 22s - loss: 2.5348e-04
# Epoch 882/1000
#  - 22s - loss: 2.6680e-04
# Epoch 883/1000
#  - 22s - loss: 2.6599e-04
# Epoch 884/1000
#  - 22s - loss: 2.5276e-04
# Epoch 885/1000
#  - 22s - loss: 2.4887e-04
# Epoch 886/1000
#  - 22s - loss: 2.4314e-04
# Epoch 887/1000
#  - 22s - loss: 2.4587e-04
# Epoch 888/1000
#  - 22s - loss: 2.4421e-04
# Epoch 889/1000
#  - 22s - loss: 2.6134e-04
# Epoch 890/1000
#  - 22s - loss: 2.6407e-04
# Epoch 891/1000
#  - 22s - loss: 2.5007e-04
# Epoch 892/1000
#  - 22s - loss: 2.4211e-04
# Epoch 893/1000
#  - 22s - loss: 2.4552e-04
# Epoch 894/1000
#  - 22s - loss: 2.5113e-04
# Epoch 895/1000
#  - 22s - loss: 2.4915e-04
# Epoch 896/1000
#  - 22s - loss: 2.4605e-04
# Epoch 897/1000
#  - 22s - loss: 2.5236e-04
# Epoch 898/1000
#  - 22s - loss: 2.4938e-04
# Epoch 899/1000
#  - 22s - loss: 2.5153e-04
# Epoch 900/1000
#  - 22s - loss: 2.4382e-04
# Epoch 901/1000
#  - 22s - loss: 2.5534e-04
# Epoch 902/1000
#  - 22s - loss: 2.4736e-04
# Epoch 903/1000
#  - 22s - loss: 2.4822e-04
# Epoch 904/1000
#  - 22s - loss: 2.4495e-04
# Epoch 905/1000
#  - 22s - loss: 2.5735e-04
# Epoch 906/1000
#  - 22s - loss: 2.5116e-04
# Epoch 907/1000
#  - 22s - loss: 2.5424e-04
# Epoch 908/1000
#  - 22s - loss: 2.4777e-04
# Epoch 909/1000
#  - 22s - loss: 2.5754e-04
# Epoch 910/1000
#  - 22s - loss: 2.5589e-04
# Epoch 911/1000
#  - 22s - loss: 2.4356e-04
# Epoch 912/1000
#  - 22s - loss: 2.3944e-04
# Epoch 913/1000
#  - 22s - loss: 2.4966e-04
# Epoch 914/1000
#  - 22s - loss: 2.5184e-04
# Epoch 915/1000
#  - 22s - loss: 2.5339e-04
# Epoch 916/1000
#  - 22s - loss: 2.5274e-04
# Epoch 917/1000
#  - 22s - loss: 2.5702e-04
# Epoch 918/1000
#  - 22s - loss: 2.5552e-04
# Epoch 919/1000
#  - 22s - loss: 2.4900e-04
# Epoch 920/1000
#  - 22s - loss: 2.4004e-04
# Epoch 921/1000
#  - 22s - loss: 2.4589e-04
# Epoch 922/1000
#  - 22s - loss: 2.4779e-04
# Epoch 923/1000
#  - 22s - loss: 2.5308e-04
# Epoch 924/1000
#  - 22s - loss: 2.4963e-04
# Epoch 925/1000
#  - 22s - loss: 2.5382e-04
# Epoch 926/1000
#  - 22s - loss: 2.4821e-04
# Epoch 927/1000
#  - 22s - loss: 2.5921e-04
# Epoch 928/1000
#  - 22s - loss: 2.6102e-04
# Epoch 929/1000
#  - 22s - loss: 2.4739e-04
# Epoch 930/1000
#  - 22s - loss: 2.3873e-04
# Epoch 931/1000
#  - 22s - loss: 2.4544e-04
# Epoch 932/1000
#  - 22s - loss: 2.4809e-04
# Epoch 933/1000
#  - 22s - loss: 2.5220e-04
# Epoch 934/1000
#  - 22s - loss: 2.4806e-04
# Epoch 935/1000
#  - 22s - loss: 2.5453e-04
# Epoch 936/1000
#  - 22s - loss: 2.4830e-04
# Epoch 937/1000
#  - 22s - loss: 2.6390e-04
# Epoch 938/1000
#  - 22s - loss: 2.7237e-04
# Epoch 939/1000
#  - 22s - loss: 2.5656e-04
# Epoch 940/1000
#  - 22s - loss: 2.4329e-04
# Epoch 941/1000
#  - 22s - loss: 2.4178e-04
# Epoch 942/1000
#  - 22s - loss: 2.4272e-04
# Epoch 943/1000
#  - 22s - loss: 2.5245e-04
# Epoch 944/1000
#  - 22s - loss: 2.5181e-04
# Epoch 945/1000
#  - 22s - loss: 2.5877e-04
# Epoch 946/1000
#  - 22s - loss: 2.7177e-04
# Epoch 947/1000
#  - 22s - loss: 2.7081e-04
# Epoch 948/1000
#  - 22s - loss: 2.5199e-04
# Epoch 949/1000
#  - 22s - loss: 2.4326e-04
# Epoch 950/1000
#  - 22s - loss: 2.4040e-04
# Epoch 951/1000
#  - 22s - loss: 2.5232e-04
# Epoch 952/1000
#  - 22s - loss: 2.4901e-04
# Epoch 953/1000
#  - 22s - loss: 2.4373e-04
# Epoch 954/1000
#  - 22s - loss: 2.5100e-04
# Epoch 955/1000
#  - 22s - loss: 2.6562e-04
# Epoch 956/1000
#  - 22s - loss: 2.5520e-04
# Epoch 957/1000
#  - 22s - loss: 2.5311e-04
# Epoch 958/1000
#  - 22s - loss: 2.5143e-04
# Epoch 959/1000
#  - 22s - loss: 2.5265e-04
# Epoch 960/1000
#  - 22s - loss: 2.4818e-04
# Epoch 961/1000
#  - 22s - loss: 2.4627e-04
# Epoch 962/1000
#  - 22s - loss: 2.4454e-04
# Epoch 963/1000
#  - 22s - loss: 2.5177e-04
# Epoch 964/1000
#  - 22s - loss: 2.5277e-04
# Epoch 965/1000
#  - 23s - loss: 2.5495e-04
# Epoch 966/1000
#  - 22s - loss: 2.7053e-04
# Epoch 967/1000
#  - 22s - loss: 2.6734e-04
# Epoch 968/1000
#  - 22s - loss: 2.4733e-04
# Epoch 969/1000
#  - 22s - loss: 2.4369e-04
# Epoch 970/1000
#  - 22s - loss: 2.4030e-04
# Epoch 971/1000
#  - 22s - loss: 2.4875e-04
# Epoch 972/1000
#  - 22s - loss: 2.4946e-04
# Epoch 973/1000
#  - 22s - loss: 2.4378e-04
# Epoch 974/1000
#  - 22s - loss: 2.5453e-04
# Epoch 975/1000
#  - 22s - loss: 2.5716e-04
# Epoch 976/1000
#  - 22s - loss: 2.5765e-04
# Epoch 977/1000
#  - 22s - loss: 2.5004e-04
# Epoch 978/1000
#  - 22s - loss: 2.4460e-04
# Epoch 979/1000
#  - 22s - loss: 2.4368e-04
# Epoch 980/1000
#  - 22s - loss: 2.4414e-04
# Epoch 981/1000
#  - 22s - loss: 2.4615e-04
# Epoch 982/1000
#  - 22s - loss: 2.4934e-04
# Epoch 983/1000
#  - 22s - loss: 2.5270e-04
# Epoch 984/1000
#  - 22s - loss: 2.5180e-04
# Epoch 985/1000
#  - 22s - loss: 2.5648e-04
# Epoch 986/1000
#  - 22s - loss: 2.6359e-04
# Epoch 987/1000
#  - 22s - loss: 2.6235e-04
# Epoch 988/1000
#  - 22s - loss: 2.4753e-04
# Epoch 989/1000
#  - 22s - loss: 2.4192e-04
# Epoch 990/1000
#  - 22s - loss: 2.4266e-04
# Epoch 991/1000
#  - 22s - loss: 2.5283e-04
# Epoch 992/1000
#  - 22s - loss: 2.4855e-04
# Epoch 993/1000
#  - 22s - loss: 2.4702e-04
# Epoch 994/1000
#  - 22s - loss: 2.5195e-04
# Epoch 995/1000
#  - 22s - loss: 2.5413e-04
# Epoch 996/1000
#  - 22s - loss: 2.5905e-04
# Epoch 997/1000
#  - 22s - loss: 2.7115e-04
# Epoch 998/1000
#  - 22s - loss: 2.6201e-04
# Epoch 999/1000
#  - 22s - loss: 2.4575e-04
# Epoch 1000/1000
#  - 22s - loss: 2.4506e-04

# %%
LSTM_log_model.fit(xLSTM_log_train, yLSTM_log_train, epochs = 150, batch_size = 2, verbose=2, shuffle = False)
# Out:
# Epoch 1/150
#  - 19s - loss: 0.0033
# Epoch 2/150
#  - 20s - loss: 0.0033
# Epoch 3/150
#  - 20s - loss: 0.0028
# Epoch 4/150
#  - 20s - loss: 0.0025
# Epoch 5/150
#  - 20s - loss: 0.0022
# Epoch 6/150
#  - 20s - loss: 0.0021
# Epoch 7/150
#  - 20s - loss: 0.0022
# Epoch 8/150
#  - 20s - loss: 0.0019
# Epoch 9/150
#  - 20s - loss: 0.0018
# Epoch 10/150
#  - 20s - loss: 0.0016
# Epoch 11/150
#  - 20s - loss: 0.0014
# Epoch 12/150
#  - 20s - loss: 0.0013
# Epoch 13/150
#  - 20s - loss: 0.0012
# Epoch 14/150
#  - 20s - loss: 0.0012
# Epoch 15/150
#  - 20s - loss: 0.0012
# Epoch 16/150
#  - 20s - loss: 0.0013
# Epoch 17/150
#  - 20s - loss: 0.0011
# Epoch 18/150
#  - 20s - loss: 0.0011
# Epoch 19/150
#  - 20s - loss: 9.7207e-04
# Epoch 20/150
#  - 20s - loss: 8.9514e-04
# Epoch 21/150
#  - 20s - loss: 8.3490e-04
# Epoch 22/150
#  - 20s - loss: 7.9212e-04
# Epoch 23/150
#  - 20s - loss: 7.6812e-04
# Epoch 24/150
#  - 20s - loss: 7.6008e-04
# Epoch 25/150
#  - 20s - loss: 7.4053e-04
# Epoch 26/150
#  - 20s - loss: 8.5976e-04
# Epoch 27/150
#  - 20s - loss: 7.6508e-04
# Epoch 28/150
#  - 20s - loss: 7.8546e-04
# Epoch 29/150
#  - 20s - loss: 7.6240e-04
# Epoch 30/150
#  - 20s - loss: 7.3859e-04
# Epoch 31/150
#  - 20s - loss: 6.8497e-04
# Epoch 32/150
#  - 20s - loss: 6.7670e-04
# Epoch 33/150
#  - 20s - loss: 6.8775e-04
# Epoch 34/150
#  - 20s - loss: 6.7577e-04
# Epoch 35/150
#  - 20s - loss: 6.8232e-04
# Epoch 36/150
#  - 20s - loss: 6.9925e-04
# Epoch 37/150
#  - 20s - loss: 7.0582e-04
# Epoch 38/150
#  - 20s - loss: 7.1263e-04
# Epoch 39/150
#  - 20s - loss: 7.1047e-04
# Epoch 40/150
#  - 20s - loss: 7.0027e-04
# Epoch 41/150
#  - 21s - loss: 6.8617e-04
# Epoch 42/150
#  - 20s - loss: 6.9076e-04
# Epoch 43/150
#  - 21s - loss: 7.1438e-04
# Epoch 44/150
#  - 21s - loss: 7.3840e-04
# Epoch 45/150
#  - 21s - loss: 7.6738e-04
# Epoch 46/150
#  - 20s - loss: 7.9916e-04
# Epoch 47/150
#  - 20s - loss: 8.5803e-04
# Epoch 48/150
#  - 21s - loss: 9.1578e-04
# Epoch 49/150
#  - 20s - loss: 9.2720e-04
# Epoch 50/150
#  - 21s - loss: 8.8535e-04
# Epoch 51/150
#  - 20s - loss: 8.2900e-04
# Epoch 52/150
#  - 20s - loss: 8.2814e-04
# Epoch 53/150
#  - 21s - loss: 8.6773e-04
# Epoch 54/150
#  - 21s - loss: 9.0432e-04
# Epoch 55/150
#  - 20s - loss: 8.7287e-04
# Epoch 56/150
#  - 20s - loss: 8.5398e-04
# Epoch 57/150
#  - 20s - loss: 8.7342e-04
# Epoch 58/150
#  - 20s - loss: 9.0231e-04
# Epoch 59/150
#  - 20s - loss: 8.8352e-04
# Epoch 60/150
#  - 20s - loss: 8.5905e-04
# Epoch 61/150
#  - 21s - loss: 8.8321e-04
# Epoch 62/150
#  - 20s - loss: 8.7265e-04
# Epoch 63/150
#  - 20s - loss: 8.1480e-04
# Epoch 64/150
#  - 20s - loss: 7.6306e-04
# Epoch 65/150
#  - 20s - loss: 7.5955e-04
# Epoch 66/150
#  - 21s - loss: 7.6130e-04
# Epoch 67/150
#  - 20s - loss: 7.6026e-04
# Epoch 68/150
#  - 21s - loss: 7.5547e-04
# Epoch 69/150
#  - 20s - loss: 7.5827e-04
# Epoch 70/150
#  - 20s - loss: 7.6582e-04
# Epoch 71/150
#  - 20s - loss: 7.5454e-04
# Epoch 72/150
#  - 20s - loss: 7.3000e-04
# Epoch 73/150
#  - 20s - loss: 7.2218e-04
# Epoch 74/150
#  - 20s - loss: 7.3186e-04
# Epoch 75/150
#  - 20s - loss: 7.3191e-04
# Epoch 76/150
#  - 20s - loss: 7.2740e-04
# Epoch 77/150
#  - 20s - loss: 7.2653e-04
# Epoch 78/150
#  - 20s - loss: 7.3009e-04
# Epoch 79/150
#  - 20s - loss: 7.1908e-04
# Epoch 80/150
#  - 20s - loss: 7.0895e-04
# Epoch 81/150
#  - 20s - loss: 7.0614e-04
# Epoch 82/150
#  - 20s - loss: 7.0309e-04
# Epoch 83/150
#  - 20s - loss: 6.8316e-04
# Epoch 84/150
#  - 20s - loss: 6.7824e-04
# Epoch 85/150
#  - 20s - loss: 6.8855e-04
# Epoch 86/150
#  - 20s - loss: 6.8864e-04
# Epoch 87/150
#  - 20s - loss: 6.7041e-04
# Epoch 88/150
#  - 20s - loss: 6.6630e-04
# Epoch 89/150
#  - 20s - loss: 6.6827e-04
# Epoch 90/150
#  - 20s - loss: 6.6758e-04
# Epoch 91/150
#  - 20s - loss: 6.5824e-04
# Epoch 92/150
#  - 20s - loss: 6.5616e-04
# Epoch 93/150
#  - 20s - loss: 6.5789e-04
# Epoch 94/150
#  - 20s - loss: 6.5076e-04
# Epoch 95/150
#  - 20s - loss: 6.3368e-04
# Epoch 96/150
#  - 20s - loss: 6.3029e-04
# Epoch 97/150
#  - 20s - loss: 6.3202e-04
# Epoch 98/150
#  - 20s - loss: 6.3114e-04
# Epoch 99/150
#  - 20s - loss: 6.1857e-04
# Epoch 100/150
#  - 20s - loss: 6.1337e-04
# Epoch 101/150
#  - 20s - loss: 6.1540e-04
# Epoch 102/150
#  - 20s - loss: 6.1210e-04
# Epoch 103/150
#  - 20s - loss: 6.0983e-04
# Epoch 104/150
#  - 20s - loss: 6.0104e-04
# Epoch 105/150
#  - 20s - loss: 5.9984e-04
# Epoch 106/150
#  - 20s - loss: 5.8443e-04
# Epoch 107/150
#  - 20s - loss: 5.8639e-04
# Epoch 108/150
#  - 20s - loss: 5.8914e-04
# Epoch 109/150
#  - 20s - loss: 5.8870e-04
# Epoch 110/150
#  - 20s - loss: 5.8360e-04
# Epoch 111/150
#  - 20s - loss: 5.8145e-04
# Epoch 112/150
#  - 20s - loss: 5.8638e-04
# Epoch 113/150
#  - 20s - loss: 5.9939e-04
# Epoch 114/150
#  - 20s - loss: 5.8248e-04
# Epoch 115/150
#  - 20s - loss: 5.4955e-04
# Epoch 116/150
#  - 20s - loss: 5.4580e-04
# Epoch 117/150
#  - 20s - loss: 5.5886e-04
# Epoch 118/150
#  - 20s - loss: 5.9172e-04
# Epoch 119/150
#  - 20s - loss: 5.7459e-04
# Epoch 120/150
#  - 20s - loss: 5.4335e-04
# Epoch 121/150
#  - 20s - loss: 5.3372e-04
# Epoch 122/150
#  - 20s - loss: 5.4281e-04
# Epoch 123/150
#  - 20s - loss: 5.3053e-04
# Epoch 124/150
#  - 20s - loss: 4.9919e-04
# Epoch 125/150
#  - 20s - loss: 4.9159e-04
# Epoch 126/150
#  - 20s - loss: 5.2850e-04
# Epoch 127/150
#  - 20s - loss: 5.1488e-04
# Epoch 128/150
#  - 20s - loss: 5.2050e-04
# Epoch 129/150
#  - 20s - loss: 5.4514e-04
# Epoch 130/150
#  - 20s - loss: 5.5145e-04
# Epoch 131/150
#  - 20s - loss: 5.1450e-04
# Epoch 132/150
#  - 20s - loss: 4.1957e-04
# Epoch 133/150
#  - 20s - loss: 4.1612e-04
# Epoch 134/150
#  - 20s - loss: 4.3551e-04
# Epoch 135/150
#  - 20s - loss: 4.2705e-04
# Epoch 136/150
#  - 20s - loss: 4.7513e-04
# Epoch 137/150
#  - 20s - loss: 4.7910e-04
# Epoch 138/150
#  - 20s - loss: 4.5353e-04
# Epoch 139/150
#  - 20s - loss: 5.6088e-04
# Epoch 140/150
#  - 20s - loss: 3.8558e-04
# Epoch 141/150
#  - 20s - loss: 3.6736e-04
# Epoch 142/150
#  - 20s - loss: 3.6091e-04
# Epoch 143/150
#  - 20s - loss: 3.5993e-04
# Epoch 144/150
#  - 20s - loss: 3.6060e-04
# Epoch 145/150
#  - 20s - loss: 3.7285e-04
# Epoch 146/150
#  - 20s - loss: 3.8942e-04
# Epoch 147/150
#  - 20s - loss: 4.0581e-04
# Epoch 148/150
#  - 21s - loss: 4.1906e-04
# Epoch 149/150
#  - 20s - loss: 4.2221e-04
# Epoch 150/150
#  - 20s - loss: 4.5095e-04

# %%
print(LSTM_model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 60, 50)            10400
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 3001
# =================================================================
# Total params: 13,401
# Trainable params: 13,401
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
print(LSTM_log_model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 60, 50)            10400
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60, 50)            20200
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 3001
# =================================================================
# Total params: 33,601
# Trainable params: 33,601
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# predicting Values using past 60 from th etrain data
inputs = RY_RW_sub_LSTM[len(RY_RW_sub_LSTM) - len(RY_LSTM_log_test) - 60:].values

# %%
xLSTM_log_train

# %%
inputs = inputs.reshape(-1,1)

# %%
inputs = scaler.transform(inputs)

# %%
xLSTM_log_test = []
for i in range(60, inputs.shape[0]):
    xLSTM_log_test.append(inputs[i-60:i,0])

# %%
xLSTM_log_test = np.array(xLSTM_log_test)

# %%
xLSTM_log_test = np.reshape(xLSTM_log_test, (xLSTM_log_test.shape[0],xLSTM_log_test.shape[1],1))

# %%
#inverse scaling
closing_price = LSTM_model.predict(x_test)
closing_price = scaler.inverse_transform(closing_price)

# %%
LSTM_preds = LSTM_log_model.predict(xLSTM_log_test)
LSTM_preds = scaler.inverse_transform(LSTM_preds)

# %%
# Testing KNN

LSTM_Log_MAPE = np.mean(np.abs(np.array(LSTM_preds-RY_LSTM_log_test)/np.abs(RY_LSTM_log_test))) 
print('MAPE: ', LSTM_Log_MAPE)

LSTM_log_mse = mean_squared_error(RY_LSTM_log_test, LSTM_preds)
print('MSE: ', LSTM_log_mse)

LSTM_log_rmse = np.sqrt(mean_squared_error(RY_LSTM_log_test, LSTM_preds))
print('RMSE: ', LSTM_log_rmse)
# Out:
# MAPE:  0.030538572657389313
# MSE:  0.019193390806968885
# RMSE:  0.13854021368169203

# %%
lstm_rms = np.sqrt(np.mean(np.power((RY_lstm_test-closing_price),2)))

# %%
lstm_log_rms = np.sqrt(np.mean(np.power((RY_LSTM_log_test-LSTM_preds),2)))

# %%
lstm_log_rms
# Out:
# 0.1385402136816921

# %%
lstm_rms
# Out:
# 5.814235763301191

# %%
dt = {'names':['Close'], 'formats':[np.int32]}
RY_LSTM_logplot_train.dtype = dt

# %%
RY_LSTM_logplot_train
# Out:
#               Close
# Date
# 2009-11-20  3.98787
# 2009-11-23  4.00861
# 2009-11-24  3.99416
# 2009-11-25  4.00077
# 2009-11-27  3.97481
# ...             ...
# 2016-11-11  4.15057
# 2016-11-14  4.15716
# 2016-11-15  4.15873
# 2016-11-16  4.15904
# 2016-11-17  4.16418
#
# [1761 rows x 1 columns]

# %%
dz = {'names':['Close'], 'formats':[np.int32]}
RY_LSTM_logplot_test.dtype = dz

# %%
RY_LSTM_logplot_test
# Out:
#               Close  Predictions
# Date
# 2016-11-18  4.16744     4.157863
# 2016-11-21  4.19525     4.162032
# 2016-11-22  4.19464     4.182730
# 2016-11-23  4.19855     4.180843
# 2016-11-25  4.19765     4.183559
# ...             ...          ...
# 2019-11-14  4.40391     4.223000
# 2019-11-15  4.40988     4.222825
# 2019-11-18  4.41098     4.223200
# 2019-11-19  4.40672     4.224860
# 2019-11-20   4.4044     4.223466
#
# [756 rows x 2 columns]

# %%
plot_length = 2517
plot_df = resample_RY.copy(deep=True).iloc[:plot_length]
plot_df['weekday'] = plot_df['Date'].dt.weekday_name

fig = px.line(plot_df, x = "Date", y = "log_Closing", color = "WeekDay",
             title = "Closing Rate Vs Time")

# %%
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6ebedab27258> in <module>()
# ----> 1 fig.show()
#
# NameError: name 'fig' is not defined

# %%
#Preparing training Data
def create_sliding_window(data, sequence_length, stride = 1):
    X_List, Y_List = [], []
    for i in range(len(data)):
        if(i + sequence_length) < len(data):
            X_List.append(data.iloc[i:i+sequence_length:stride, :].values)
            Y_List.append(data.iloc[i+sequence_length, -1])
    return np.array(X_List), np.array(Y_List)

train_split = 0.7
n_train = int(train_split * len(resample_RY))
n_test = len(resample_RY) - n_train

feature = ['Year','Month','WeekofYear','WeekDay','log_Closing']
feature_array = resample_RY[feature].values

#Fit Scaler only on  Training Features. Define a scaler to normalize the data. 
#MinMaxScalar scales all the data to be in the region of 0 and 1
# Check: You normalize both test and train data with respect to training data. Because you are not supposed to have access to test data
feature_scaler = MinMaxScaler()
feature_scaler.fit(feature_array[:n_train])

#Fit Scaler only on Training target values(test)
target_scaler = MinMaxScaler()
target_scaler.fit(feature_array[:n_train, -1].reshape(-1,1))

#Transform on both Training and Test Data
scaled_array = pd.DataFrame(feature_scaler.transform(feature_array), columns=feature)

# we take 5 days and try to predict the 6th day. Move the 5 day window by 1 and then again predict the 6th day
sequence_length = 5
x, y = create_sliding_window(scaled_array, sequence_length)

x_train = x[:n_train]
y_train = y[:n_train]

xdef_test = x[n_train:]
y_test = y[n_train:]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %%
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-581-b6cf670020b2> in <module>
# ----> 1 print('The scikit-learn version is {}.'.format(sklearn.__version__))
#
# NameError: name 'sklearn' is not defined

# %%
class BayesianLSTM(nn.Module):
        #Construct function
        def __init__(self, n_features, output_length):
        
            super(BayesianLSTM, self).__init__()
            #Hidden dimensions        
            self.hidden_size_1 = 128
            self.hidden_size_2 = 32 
            self.n_layers = 1
           # batch_first=True causes input/output tensors to be of shape
            # (batch_dim, seq_dim, feature_dim)            
        
            self.lstm1 = nn.LSTM(n_features, self.hidden_size_1,num_layers=1, batch_first = True)
            self.lstm2 = nn.LSTM(self.hidden_size_1, self.hidden_size_2, num_layers=1, batch_first = True)
            # Readout layer
            self.dense = nn.Linear(self.hidden_size_2, output_length)
            self.loss_fn = nn.MSELoss()
        
        def forward(self, x):
            batch_size, seq_len, _ = x.size()
            
            hidden = self.init_hidden1(batch_size)
            output, _ = self.lstm1(x, hidden)
            output = F.dropout(output, p=0.5, training = True)
            
            state = self.init_hidden2(batch_size)
            output, state = self.lstm2(output, state)
            output = F.dropout(output, p =0.5, training = True)
            ,
            output = self.dense(state[0].squeeze(0))
            
            return output
        
        def init_hidden1(self, batch_size):
            #Initialize hidden state with 0
            hidden_state = Variable(torch.zeros(self.n_layers, batch_size, self.hidden_size_1))
            #Initialize Cell State
            cell_state = Variable(torch.zeros(self.n_layers, batch_size, self.hidden_size_1))
            return hidden_state, cell_state
        
        def init_hidden2(self, batch_size):
            #Initialize hidden state with 0
            hidden_state = Variable(torch.zeros(self.n_layers, batch_size, self.hidden_size_2))
            #Initialize Cell State
            cell_state = Variable(torch.zeros(self.n_layers, batch_size, self.hidden_size_2))
            return hidden_state, cell_state
        
        def loss(self, pred, truth):
            return torch.sqrt(self.loss_fn(pred, truth))
        
        def predict(self, X):
            return self(torch.tensor(X, dtype = torch.float32)).view(-1).detach().numpy()

# %%
#instantiate Bayesian LSTM model
n_features = scaled_array.shape[-1] #o/p 5
sequence_length = 5
output_length = 1

#pass agruements to the class
bayesian_lstm = BayesianLSTM(n_features=n_features, output_length=output_length)

#instantiate Loss Class use cross entropy for classification problem and MSE for Regression
criterion = torch.nn.MSELoss() 


#learning rate = 0.1
optimizer = torch.optim.Adam(bayesian_lstm.parameters(), lr = 0.01)

batch_size = 128 
n_epochs = 150

# %%
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.21.3.

# %%
n_features
# Out:
# 5

# %%
bayesian_lstm.train()

for e in range(1, n_epochs+1):
    for b in range(0, len(x_train), batch_size):
        features = x_train[b:b+batch_size,:,:]
        target = y_train[b:b+batch_size]
        
        x_batch = torch.tensor(features,dtype = torch.float32)
        y_batch = torch.tensor(target,dtype = torch.float32)
        
        output = bayesian_lstm(x_batch)
        # Calculate Loss: softmax --> MSE
        loss = torch.sqrt(criterion(output.view(-1), y_batch))
        
        # Getting gradients w.r.t. parameters
        loss.backward()
        # Updating parameters
        optimizer.step()
        # Clear gradients w.r.t. parameters
        optimizer.zero_grad()
        
    if e % 10 == 0:
        print('epoch:', e, 'loss:', loss.item())
# Out:
# epoch: 10 loss: 0.17628955841064453
# epoch: 20 loss: 0.0658060759305954
# epoch: 30 loss: 0.08121701329946518
# epoch: 40 loss: 0.05105665326118469
# epoch: 50 loss: 0.0337093286216259
# epoch: 60 loss: 0.06234809383749962
# epoch: 70 loss: 0.02205415442585945
# epoch: 80 loss: 0.02559736929833889
# epoch: 90 loss: 0.022479387000203133
# epoch: 100 loss: 0.02333284541964531
# epoch: 110 loss: 0.018135525286197662
# epoch: 120 loss: 0.07830693572759628
# epoch: 130 loss: 0.07735367119312286
# epoch: 140 loss: 0.031113246455788612
# epoch: 150 loss: 0.04340587556362152

# %%
training_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-586-5750aa0cad81> in <module>
# ----> 1 training_df
#
# NameError: name 'training_df' is not defined

# %%
#Model Evaluation

offset = sequence_length

def inverse_transform(y):
    return target_scaler.inverse_transform(y.reshape(-1,1))

training_df = pd.DataFrame()
training_df['Date'] = resample_RY['Date'].iloc[offset:n_train + offset:1]
#Apply bayesin Function
training_predictions = bayesian_lstm.predict(x_train)
training_df['log_Closing'] = inverse_transform(training_predictions)
training_df['Source'] = 'Training Prediction'

training_true_df = pd.DataFrame()
training_true_df['Date'] = training_df['Date']
training_true_df['log_Closing'] = resample_RY['log_Closing'].iloc[offset:n_train + offset:1] 
training_true_df['Source'] = 'True Values'

testing_df = pd.DataFrame()
testing_df['Date'] = resample_RY['Date'].iloc[n_train + offset::1]
#Apply bayesin Function
testing_predictions = bayesian_lstm.predict(xdef_test)
testing_df['log_Closing'] = inverse_transform(testing_predictions)
testing_df['Source'] = 'Testing Prediction'

testing_true_df = pd.DataFrame()
testing_true_df['Date'] = testing_df['Date']
testing_true_df['log_Closing'] = resample_RY['log_Closing'].iloc[n_train + offset::1]
testing_true_df['Source'] = 'True Values'

Evaluation = pd.concat([training_df,
                        testing_df,
                        training_true_df,testing_true_df
                       ], axis = 0, sort = True)

# %%
testing_predictions = bayesian_lstm.predict(xdef_test)

# %%
testing_df
# Out:
#                  Date  log_Closing              Source
# Date
# 2016-11-28 2016-11-28     4.196540  Testing Prediction
# 2016-11-29 2016-11-29     4.222424  Testing Prediction
# 2016-11-30 2016-11-30     4.243239  Testing Prediction
# 2016-12-01 2016-12-01     4.183474  Testing Prediction
# 2016-12-02 2016-12-02     4.208267  Testing Prediction
# ...               ...          ...                 ...
# 2019-11-14 2019-11-14     4.354757  Testing Prediction
# 2019-11-15 2019-11-15     4.365109  Testing Prediction
# 2019-11-18 2019-11-18     4.370879  Testing Prediction
# 2019-11-19 2019-11-19     4.364688  Testing Prediction
# 2019-11-20 2019-11-20     4.367342  Testing Prediction
#
# [751 rows x 3 columns]

# %%
testing_true_df
# Out:
#                  Date  log_Closing       Source
# Date
# 2016-11-28 2016-11-28     4.197052  True Values
# 2016-11-29 2016-11-29     4.205439  True Values
# 2016-11-30 2016-11-30     4.171614  True Values
# 2016-12-01 2016-12-01     4.181439  True Values
# 2016-12-02 2016-12-02     4.190715  True Values
# ...               ...          ...          ...
# 2019-11-14 2019-11-14     4.403910  True Values
# 2019-11-15 2019-11-15     4.409885  True Values
# 2019-11-18 2019-11-18     4.410978  True Values
# 2019-11-19 2019-11-19     4.406719  True Values
# 2019-11-20 2019-11-20     4.404399  True Values
#
# [751 rows x 3 columns]

# %%
print(bayesian_lstm)
# Out:
# BayesianLSTM(
#   (lstm1): LSTM(5, 128, batch_first=True)
#   (lstm2): LSTM(128, 32, batch_first=True)
#   (dense): Linear(in_features=32, out_features=1, bias=True)
#   (loss_fn): MSELoss()
# )

# %%
print(LSTM_model.summary())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-6868eb12ec52> in <module>
# ----> 1 print(bayesian_lstm.summary())
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#     537                 return modules[name]
#     538         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 539             type(self).__name__, name))
#     540
#     541     def __setattr__(self, name, value):
#
# AttributeError: 'BayesianLSTM' object has no attribute 'summary'

# %%
BLSTM_RMSE = np.sqrt(np.mean(np.power(testing_true_df['log_Closing'] - testing_df['log_Closing'],2)))

# %%
# Testing KNN

BLSTM_Log_MAPE = np.mean(np.abs(np.array(testing_df['log_Closing']-testing_true_df['log_Closing'])/np.abs(testing_true_df['log_Closing']))) 
print('MAPE: ', BLSTM_Log_MAPE)

BLSTM_log_mse = mean_squared_error(testing_true_df['log_Closing'], testing_df['log_Closing'])
print('MSE: ', BLSTM_log_mse)

BLSTM_log_rmse = np.sqrt(mean_squared_error(testing_true_df['log_Closing'], testing_df['log_Closing']))
print('RMSE: ', BLSTM_log_rmse)
# Out:
# MAPE:  0.004635376110782879
# MSE:  0.0006562589536092356
# RMSE:  0.025617551670861046

# %%
BLSTM_RMSE
# Out:
# 2.3700411002797597

# %%
Evaluation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-557-32f4d1a35897> in <module>
# ----> 1 Evaluation
#
# NameError: name 'Evaluation' is not defined

# %%
fig = px.line(Evaluation.loc[Evaluation['Date'].between('2010-05-30','2019-01-31')],
              x ="Date",
             y = "Close",
             color = "Source",
             title = "Closing rates in CAD vs Time in Years")

fig.show()
# Out:
# <div>
#
#
#             <div id="e1f41b47-77c1-4378-87b0-ea612f0cccaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1f41b47-77c1-4378-87b0-ea612f0cccaf")) {
#                     Plotly.newPlot(
#                         'e1f41b47-77c1-4378-87b0-ea612f0cccaf',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Source=Training Prediction<br>Date=%{x}<br>Close=%{y}", "legendgroup": "Source=Training Prediction", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Source=Training Prediction", "showlegend": true, "type": "scattergl", "x": ["2010-06-01T00:00:00", "2010-06-02T00:00:00", "2010-06-03T00:00:00", "2010-06-04T00:00:00", "2010-06-07T00:00:00", "2010-06-08T00:00:00", "2010-06-09T00:00:00", "2010-06-10T00:00:00", "2010-06-11T00:00:00", "2010-06-14T00:00:00", "2010-06-15T00:00:00", "2010-06-16T00:00:00", "2010-06-17T00:00:00", "2010-06-18T00:00:00", "2010-06-21T00:00:00", "2010-06-22T00:00:00", "2010-06-23T00:00:00", "2010-06-24T00:00:00", "2010-06-25T00:00:00", "2010-06-28T00:00:00", "2010-06-29T00:00:00", "2010-06-30T00:00:00", "2010-07-01T00:00:00", "2010-07-02T00:00:00", "2010-07-06T00:00:00", "2010-07-07T00:00:00", "2010-07-08T00:00:00", "2010-07-09T00:00:00", "2010-07-12T00:00:00", "2010-07-13T00:00:00", "2010-07-14T00:00:00", "2010-07-15T00:00:00", "2010-07-16T00:00:00", "2010-07-19T00:00:00", "2010-07-20T00:00:00", "2010-07-21T00:00:00", "2010-07-22T00:00:00", "2010-07-23T00:00:00", "2010-07-26T00:00:00", "2010-07-27T00:00:00", "2010-07-28T00:00:00", "2010-07-29T00:00:00", "2010-07-30T00:00:00", "2010-08-02T00:00:00", "2010-08-03T00:00:00", "2010-08-04T00:00:00", "2010-08-05T00:00:00", "2010-08-06T00:00:00", "2010-08-09T00:00:00", "2010-08-10T00:00:00", "2010-08-11T00:00:00", "2010-08-12T00:00:00", "2010-08-13T00:00:00", "2010-08-16T00:00:00", "2010-08-17T00:00:00", "2010-08-18T00:00:00", "2010-08-19T00:00:00", "2010-08-20T00:00:00", "2010-08-23T00:00:00", "2010-08-24T00:00:00", "2010-08-25T00:00:00", "2010-08-26T00:00:00", "2010-08-27T00:00:00", "2010-08-30T00:00:00", "2010-08-31T00:00:00", "2010-09-01T00:00:00", "2010-09-02T00:00:00", "2010-09-03T00:00:00", "2010-09-07T00:00:00", "2010-09-08T00:00:00", "2010-09-09T00:00:00", "2010-09-10T00:00:00", "2010-09-13T00:00:00", "2010-09-14T00:00:00", "2010-09-15T00:00:00", "2010-09-16T00:00:00", "2010-09-17T00:00:00", "2010-09-20T00:00:00", "2010-09-21T00:00:00", "2010-09-22T00:00:00", "2010-09-23T00:00:00", "2010-09-24T00:00:00", "2010-09-27T00:00:00", "2010-09-28T00:00:00", "2010-09-29T00:00:00", "2010-09-30T00:00:00", "2010-10-01T00:00:00", "2010-10-04T00:00:00", "2010-10-05T00:00:00", "2010-10-06T00:00:00", "2010-10-07T00:00:00", "2010-10-08T00:00:00", "2010-10-11T00:00:00", "2010-10-12T00:00:00", "2010-10-13T00:00:00", "2010-10-14T00:00:00", "2010-10-15T00:00:00", "2010-10-18T00:00:00", "2010-10-19T00:00:00", "2010-10-20T00:00:00", "2010-10-21T00:00:00", "2010-10-22T00:00:00", "2010-10-25T00:00:00", "2010-10-26T00:00:00", "2010-10-27T00:00:00", "2010-10-28T00:00:00", "2010-10-29T00:00:00", "2010-11-01T00:00:00", "2010-11-02T00:00:00", "2010-11-03T00:00:00", "2010-11-04T00:00:00", "2010-11-05T00:00:00", "2010-11-08T00:00:00", "2010-11-09T00:00:00", "2010-11-10T00:00:00", "2010-11-11T00:00:00", "2010-11-12T00:00:00", "2010-11-15T00:00:00", "2010-11-16T00:00:00", "2010-11-17T00:00:00", "2010-11-18T00:00:00", "2010-11-19T00:00:00", "2010-11-22T00:00:00", "2010-11-23T00:00:00", "2010-11-24T00:00:00", "2010-11-26T00:00:00", "2010-11-29T00:00:00", "2010-11-30T00:00:00", "2010-12-01T00:00:00", "2010-12-02T00:00:00", "2010-12-03T00:00:00", "2010-12-06T00:00:00", "2010-12-07T00:00:00", "2010-12-08T00:00:00", "2010-12-09T00:00:00", "2010-12-10T00:00:00", "2010-12-13T00:00:00", "2010-12-14T00:00:00", "2010-12-15T00:00:00", "2010-12-16T00:00:00", "2010-12-17T00:00:00", "2010-12-20T00:00:00", "2010-12-21T00:00:00", "2010-12-22T00:00:00", "2010-12-23T00:00:00", "2010-12-27T00:00:00", "2010-12-28T00:00:00", "2010-12-29T00:00:00", "2010-12-30T00:00:00", "2010-12-31T00:00:00", "2011-01-03T00:00:00", "2011-01-04T00:00:00", "2011-01-05T00:00:00", "2011-01-06T00:00:00", "2011-01-07T00:00:00", "2011-01-10T00:00:00", "2011-01-11T00:00:00", "2011-01-12T00:00:00", "2011-01-13T00:00:00", "2011-01-14T00:0 ...

# %%
Evaluation.dtypes
# Out:
# Date           datetime64[ns]
# Source                 object
# log_Closing           float64
# dtype: object

# %%
Evaluation['index'] = Evaluation['Date'].astype(str)

# %%
Evaluation
# Out:
#                  Date               Source  log_Closing
# Date
# 2009-12-27 2009-12-27  Training Prediction     3.633101
# 2010-01-03 2010-01-03  Training Prediction     3.639474
# 2010-01-10 2010-01-10  Training Prediction     3.634306
# 2010-01-17 2010-01-17  Training Prediction     3.634044
# 2010-01-24 2010-01-24  Training Prediction     3.633455
# ...               ...                  ...          ...
# 2016-11-27 2016-11-27          True Values     4.196525
# 2016-12-04 2016-12-04          True Values     4.189321
# 2016-12-11 2016-12-11          True Values     4.206601
# 2016-12-18 2016-12-18          True Values     4.230360
# 2016-12-25 2016-12-25          True Values     4.224846
#
# [1464 rows x 3 columns]

# %%
len(experiment_predictions)
# Out:
# 751

# %%
len(test_uncertainity_df)
# Out:
# 1761

# %%
len(xdef_test)
# Out:
# 751

# %%
n_experiments =1761

test_uncertainty_df = pd.DataFrame()
test_uncertainty_df['Date'] = testing_df['Date']

#Error ValueError: Length of values does not match length of index
for i in range(n_experiments):
    experiment_predictions = bayesian_lstm.predict(xdef_test)
    test_uncertainty_df['Close{}'.format(i)]  = inverse_transform(experiment_predictions)
    
Closing_df = test_uncertainty_df.filter(like = 'Close', axis = 1)

test_uncertainty_df['Close_mean'] = Closing_df.mean(axis=1)
test_uncertainty_df['Close_std'] = Closing_df.std(axis=1)

test_uncertainty_df = test_uncertainty_df[['Date', 'Close_mean','Close_std']]

# %%
test_uncertainty_df['lower_bound'] = test_uncertainty_df['Close_mean'] - 3*test_uncertainty_df['Close_std']
test_uncertainty_df['upper_bound'] = test_uncertainty_df['Close_mean'] + 3*test_uncertainty_df['Close_std']

# %%
import plotly.graph_objects as go

test_uncertainty_plot_df = test_uncertainty_df.copy(deep=True)
test_uncertainty_plot_df = test_uncertainty_plot_df.loc[test_uncertainty_plot_df['Date'].between('2009-11-20', '2019-11-15')]
truth_uncertainty_plot_df = testing_true_df.copy(deep=True)
truth_uncertainty_plot_df = truth_uncertainty_plot_df.loc[testing_true_df['Date'].between('2009-11-20', '2019-11-15')]

upper_trace = go.Scatter(
    x=test_uncertainty_plot_df['Date'],
    y=test_uncertainty_plot_df['upper_bound'],
    mode='lines',
    fill=None,
    name='99% Upper Confidence Bound'
    )
lower_trace = go.Scatter(
    x=test_uncertainty_plot_df['Date'],
    y=test_uncertainty_plot_df['lower_bound'],
    mode='lines',
    fill='tonexty',
    fillcolor='rgba(255, 211, 0, 0.5)',
    name='99% Lower Confidence Bound'
    )
real_trace = go.Scatter(
    x=truth_uncertainty_plot_df['Date'],
    y=truth_uncertainty_plot_df['Close'],
    mode='lines',
    fill=None,
    name='Real Values'
    )

data = [upper_trace, lower_trace, real_trace]

fig = go.Figure(data=data)
fig.update_layout(title='Uncertainty Quantification for Closing Price of Test Data',
                   xaxis_title='Time',
                   yaxis_title='Close Price CAD)')

fig.show()
# Out:
# <div>
#
#
#             <div id="3e751a63-cf09-4af9-a1ae-8fd73f9c321f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3e751a63-cf09-4af9-a1ae-8fd73f9c321f")) {
#                     Plotly.newPlot(
#                         '3e751a63-cf09-4af9-a1ae-8fd73f9c321f',
#                         [{"mode": "lines", "name": "99% Upper Confidence Bound", "type": "scatter", "x": ["2016-11-28T00:00:00", "2016-11-29T00:00:00", "2016-11-30T00:00:00", "2016-12-01T00:00:00", "2016-12-02T00:00:00", "2016-12-05T00:00:00", "2016-12-06T00:00:00", "2016-12-07T00:00:00", "2016-12-08T00:00:00", "2016-12-09T00:00:00", "2016-12-12T00:00:00", "2016-12-13T00:00:00", "2016-12-14T00:00:00", "2016-12-15T00:00:00", "2016-12-16T00:00:00", "2016-12-19T00:00:00", "2016-12-20T00:00:00", "2016-12-21T00:00:00", "2016-12-22T00:00:00", "2016-12-23T00:00:00", "2016-12-27T00:00:00", "2016-12-28T00:00:00", "2016-12-29T00:00:00", "2016-12-30T00:00:00", "2017-01-03T00:00:00", "2017-01-04T00:00:00", "2017-01-05T00:00:00", "2017-01-06T00:00:00", "2017-01-09T00:00:00", "2017-01-10T00:00:00", "2017-01-11T00:00:00", "2017-01-12T00:00:00", "2017-01-13T00:00:00", "2017-01-17T00:00:00", "2017-01-18T00:00:00", "2017-01-19T00:00:00", "2017-01-20T00:00:00", "2017-01-23T00:00:00", "2017-01-24T00:00:00", "2017-01-25T00:00:00", "2017-01-26T00:00:00", "2017-01-27T00:00:00", "2017-01-30T00:00:00", "2017-01-31T00:00:00", "2017-02-01T00:00:00", "2017-02-02T00:00:00", "2017-02-03T00:00:00", "2017-02-06T00:00:00", "2017-02-07T00:00:00", "2017-02-08T00:00:00", "2017-02-09T00:00:00", "2017-02-10T00:00:00", "2017-02-13T00:00:00", "2017-02-14T00:00:00", "2017-02-15T00:00:00", "2017-02-16T00:00:00", "2017-02-17T00:00:00", "2017-02-21T00:00:00", "2017-02-22T00:00:00", "2017-02-23T00:00:00", "2017-02-24T00:00:00", "2017-02-27T00:00:00", "2017-02-28T00:00:00", "2017-03-01T00:00:00", "2017-03-02T00:00:00", "2017-03-03T00:00:00", "2017-03-06T00:00:00", "2017-03-07T00:00:00", "2017-03-08T00:00:00", "2017-03-09T00:00:00", "2017-03-10T00:00:00", "2017-03-13T00:00:00", "2017-03-14T00:00:00", "2017-03-15T00:00:00", "2017-03-16T00:00:00", "2017-03-17T00:00:00", "2017-03-20T00:00:00", "2017-03-21T00:00:00", "2017-03-22T00:00:00", "2017-03-23T00:00:00", "2017-03-24T00:00:00", "2017-03-27T00:00:00", "2017-03-28T00:00:00", "2017-03-29T00:00:00", "2017-03-30T00:00:00", "2017-03-31T00:00:00", "2017-04-03T00:00:00", "2017-04-04T00:00:00", "2017-04-05T00:00:00", "2017-04-06T00:00:00", "2017-04-07T00:00:00", "2017-04-10T00:00:00", "2017-04-11T00:00:00", "2017-04-12T00:00:00", "2017-04-13T00:00:00", "2017-04-17T00:00:00", "2017-04-18T00:00:00", "2017-04-19T00:00:00", "2017-04-20T00:00:00", "2017-04-21T00:00:00", "2017-04-24T00:00:00", "2017-04-25T00:00:00", "2017-04-26T00:00:00", "2017-04-27T00:00:00", "2017-04-28T00:00:00", "2017-05-01T00:00:00", "2017-05-02T00:00:00", "2017-05-03T00:00:00", "2017-05-04T00:00:00", "2017-05-05T00:00:00", "2017-05-08T00:00:00", "2017-05-09T00:00:00", "2017-05-10T00:00:00", "2017-05-11T00:00:00", "2017-05-12T00:00:00", "2017-05-15T00:00:00", "2017-05-16T00:00:00", "2017-05-17T00:00:00", "2017-05-18T00:00:00", "2017-05-19T00:00:00", "2017-05-22T00:00:00", "2017-05-23T00:00:00", "2017-05-24T00:00:00", "2017-05-25T00:00:00", "2017-05-26T00:00:00", "2017-05-30T00:00:00", "2017-05-31T00:00:00", "2017-06-01T00:00:00", "2017-06-02T00:00:00", "2017-06-05T00:00:00", "2017-06-06T00:00:00", "2017-06-07T00:00:00", "2017-06-08T00:00:00", "2017-06-09T00:00:00", "2017-06-12T00:00:00", "2017-06-13T00:00:00", "2017-06-14T00:00:00", "2017-06-15T00:00:00", "2017-06-16T00:00:00", "2017-06-19T00:00:00", "2017-06-20T00:00:00", "2017-06-21T00:00:00", "2017-06-22T00:00:00", "2017-06-23T00:00:00", "2017-06-26T00:00:00", "2017-06-27T00:00:00", "2017-06-28T00:00:00", "2017-06-29T00:00:00", "2017-06-30T00:00:00", "2017-07-03T00:00:00", "2017-07-05T00:00:00", "2017-07-06T00:00:00", "2017-07-07T00:00:00", "2017-07-10T00:00:00", "2017-07-11T00:00:00", "2017-07-12T00:00:00", "2017-07-13T00:00:00", "2017-07-14T00:00:00", "2017-07-17T00:00:00", "2017-07-18T00:00:00", "2017-07-19T00:00:00", "2017-07-20T00:00:00", "2017-07-21T00:00:00", "2017-07-24T00:00:00", "2017-07-25T00:00:00", "2017-07-26T00:00:00", "2017-07-27T00:00:00", "2017-07-28T00:00:00", "2017-07-31T00:00:00", "2017-0 ...

# %%
test_uncertainty_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-198-376843dc43b0> in <module>
# ----> 1 test_uncertainty_df
#
# NameError: name 'test_uncertainty_df' is not defined

# %%
bounds_df = pd.DataFrame()

# Using 99% confidence bounds
bounds_df['lower_bound'] = test_uncertainty_plot_df['lower_bound']
bounds_df['prediction'] = test_uncertainty_plot_df['Close_mean']
bounds_df['real_value'] = truth_uncertainty_plot_df['Close']
bounds_df['upper_bound'] = test_uncertainty_plot_df['upper_bound']

bounds_df['contained'] = ((bounds_df['real_value'] >= bounds_df['lower_bound']) &
                          (bounds_df['real_value'] <= bounds_df['upper_bound']))

print("Proportion of points contained within 99% confidence interval:", 
      bounds_df['contained'].mean())
# Out:
# Proportion of points contained within 99% confidence interval: 0.0213903743315508
